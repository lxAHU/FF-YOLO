# %%
#-------------------------------------#
#       对数据集进行训练
#-------------------------------------#
import datetime
import os
from functools import partial

import numpy as np
import torch
import torch.backends.cudnn as cudnn
import torch.distributed as dist
import torch.nn as nn
import torch.optim as optim
from torch import nn
from torch.utils.data import DataLoader

import nbimporter

from nets.yolo import YoloBody
from nets.yolo_training import (YOLOLoss, get_lr_scheduler, set_optimizer_lr,
                                weights_init)
from utils.callbacks import EvalCallback, LossHistory
from utils.dataloader import YoloDataset, yolo_dataset_collate
from utils.utils import (download_weights, get_anchors, get_classes,
                         seed_everything, show_config, worker_init_fn)
from utils.utils_fit import fit_one_epoch

'''
训练自己的目标检测模型一定需要注意以下几点：
1、训练前仔细检查自己的格式是否满足要求，该库要求数据集格式为VOC格式，需要准备好的内容有输入图片和标签
   输入图片为.jpg图片，无需固定大小，传入训练前会自动进行resize。
   灰度图会自动转成RGB图片进行训练，无需自己修改。
   输入图片如果后缀非jpg，需要自己批量转成jpg后再开始训练。

   标签为.xml格式，文件中会有需要检测的目标信息，标签文件和输入图片文件相对应。

2、损失值的大小用于判断是否收敛，比较重要的是有收敛的趋势，即验证集损失不断下降，如果验证集损失基本上不改变的话，模型基本上就收敛了。
   损失值的具体大小并没有什么意义，大和小只在于损失的计算方式，并不是接近于0才好。如果想要让损失好看点，可以直接到对应的损失函数里面除上10000。
   训练过程中的损失值会保存在logs文件夹下的loss_%Y_%m_%d_%H_%M_%S文件夹中
   
3、训练好的权值文件保存在logs文件夹中，每个训练世代（Epoch）包含若干训练步长（Step），每个训练步长（Step）进行一次梯度下降。
   如果只是训练了几个Step是不会保存的，Epoch和Step的概念要捋清楚一下。
'''
if __name__ == "__main__":
    #---------------------------------#
    #   Cuda    是否使用Cuda
    #           没有GPU可以设置成False
    #---------------------------------#
    Cuda            = False
    #----------------------------------------------#
    #   Seed    用于固定随机种子
    #           使得每次独立训练都可以获得一样的结果
    #----------------------------------------------#
    seed            = 11
    #---------------------------------------------------------------------#
    #   distributed     用于指定是否使用单机多卡分布式运行
    #                   终端指令仅支持Ubuntu。CUDA_VISIBLE_DEVICES用于在Ubuntu下指定显卡。
    #                   Windows系统下默认使用DP模式调用所有显卡，不支持DDP。
    #   DP模式：
    #       设置            distributed = False
    #       在终端中输入    CUDA_VISIBLE_DEVICES=0,1 python train.py
    #   DDP模式：
    #       设置            distributed = True
    #       在终端中输入    CUDA_VISIBLE_DEVICES=0,1 python -m torch.distributed.launch --nproc_per_node=2 train.py
    #---------------------------------------------------------------------#
    distributed     = False
    #---------------------------------------------------------------------#
    #   sync_bn     是否使用sync_bn，DDP模式多卡可用
    #---------------------------------------------------------------------#
    sync_bn         = False
    #---------------------------------------------------------------------#
    #   fp16        是否使用混合精度训练
    #               可减少约一半的显存、需要pytorch1.7.1以上
    #---------------------------------------------------------------------#
    fp16            = False
    #---------------------------------------------------------------------#
    #   classes_path    指向model_data下的txt，与自己训练的数据集相关 
    #                   训练前一定要修改classes_path，使其对应自己的数据集
    #---------------------------------------------------------------------#
    classes_path    = 'model_data/fire_classes.txt'
    #---------------------------------------------------------------------#
    #   anchors_path    代表先验框对应的txt文件，一般不修改。
    #   anchors_mask    用于帮助代码找到对应的先验框，一般不修改。
    #---------------------------------------------------------------------#
    anchors_path    = 'model_data/yolo_anchors.txt'
    anchors_mask    = [[6, 7, 8], [3, 4, 5], [0, 1, 2]]
    #----------------------------------------------------------------------------------------------------------------------------#
    #   权值文件的下载请看README，可以通过网盘下载。模型的 预训练权重 对不同数据集是通用的，因为特征是通用的。
    #   模型的 预训练权重 比较重要的部分是 主干特征提取网络的权值部分，用于进行特征提取。
    #   预训练权重对于99%的情况都必须要用，不用的话主干部分的权值太过随机，特征提取效果不明显，网络训练的结果也不会好
    #
    #   如果训练过程中存在中断训练的操作，可以将model_path设置成logs文件夹下的权值文件，将已经训练了一部分的权值再次载入。
    #   同时修改下方的 冻结阶段 或者 解冻阶段 的参数，来保证模型epoch的连续性。
    #   
    #   当model_path = ''的时候不加载整个模型的权值。
    #
    #   此处使用的是整个模型的权重，因此是在train.py进行加载的，下面的pretrain不影响此处的权值加载。
    #   如果想要让模型从主干的预训练权值开始训练，则设置model_path = ''，下面的pretrain = True，此时仅加载主干。
    #   如果想要让模型从0开始训练，则设置model_path = ''，下面的pretrain = Fasle，Freeze_Train = Fasle，此时从0开始训练，且没有冻结主干的过程。
    #   
    #   一般来讲，网络从0开始的训练效果会很差，因为权值太过随机，特征提取效果不明显，因此非常、非常、非常不建议大家从0开始训练！
    #   如果一定要从0开始，可以了解imagenet数据集，首先训练分类模型，获得网络的主干部分权值，分类模型的 主干部分 和该模型通用，基于此进行训练。
    #----------------------------------------------------------------------------------------------------------------------------#
    model_path      = 'model_data/yolov3_efficientnet_b2_voc.pth'
    #------------------------------------------------------#
    #   input_shape     输入的shape大小，一定要是32的倍数
    #------------------------------------------------------#
    input_shape     = [416, 416]
    #------------------------------------------------------#
    #   efficientnet的版本
    #   phi = 0代表efficientnet-B0-yolov3
    #   phi = 1代表efficientnet-B1-yolov3
    #   phi = 2代表efficientnet-B2-yolov3   
    #   …… 以此类推
    #------------------------------------------------------#
    phi             = 2
    #----------------------------------------------------------------------------------------------------------------------------#
    #   pretrained      是否使用主干网络的预训练权重，此处使用的是主干的权重，因此是在模型构建的时候进行加载的。
    #                   如果设置了model_path，则主干的权值无需加载，pretrained的值无意义。
    #                   如果不设置model_path，pretrained = True，此时仅加载主干开始训练。
    #                   如果不设置model_path，pretrained = False，Freeze_Train = Fasle，此时从0开始训练，且没有冻结主干的过程。
    #----------------------------------------------------------------------------------------------------------------------------#
    pretrained      = False
    
    #----------------------------------------------------------------------------------------------------------------------------#
    #   训练分为两个阶段，分别是冻结阶段和解冻阶段。设置冻结阶段是为了满足机器性能不足的同学的训练需求。
    #   冻结训练需要的显存较小，显卡非常差的情况下，可设置Freeze_Epoch等于UnFreeze_Epoch，此时仅仅进行冻结训练。
    #      
    #   在此提供若干参数设置建议，各位训练者根据自己的需求进行灵活调整：
    #   （一）从整个模型的预训练权重开始训练： 
    #       Adam：
    #           Init_Epoch = 0，Freeze_Epoch = 50，UnFreeze_Epoch = 100，Freeze_Train = True，optimizer_type = 'adam'，Init_lr = 1e-3，weight_decay = 0。（冻结）
    #           Init_Epoch = 0，UnFreeze_Epoch = 100，Freeze_Train = False，optimizer_type = 'adam'，Init_lr = 1e-3，weight_decay = 0。（不冻结）
    #       SGD：
    #           Init_Epoch = 0，Freeze_Epoch = 50，UnFreeze_Epoch = 300，Freeze_Train = True，optimizer_type = 'sgd'，Init_lr = 1e-2，weight_decay = 5e-4。（冻结）
    #           Init_Epoch = 0，UnFreeze_Epoch = 300，Freeze_Train = False，optimizer_type = 'sgd'，Init_lr = 1e-2，weight_decay = 5e-4。（不冻结）
    #       其中：UnFreeze_Epoch可以在100-300之间调整。
    #   （二）从主干网络的预训练权重开始训练：
    #       Adam：
    #           Init_Epoch = 0，Freeze_Epoch = 50，UnFreeze_Epoch = 100，Freeze_Train = True，optimizer_type = 'adam'，Init_lr = 1e-3，weight_decay = 0。（冻结）
    #           Init_Epoch = 0，UnFreeze_Epoch = 100，Freeze_Train = False，optimizer_type = 'adam'，Init_lr = 1e-3，weight_decay = 0。（不冻结）
    #       SGD：
    #           Init_Epoch = 0，Freeze_Epoch = 50，UnFreeze_Epoch = 300，Freeze_Train = True，optimizer_type = 'sgd'，Init_lr = 1e-2，weight_decay = 5e-4。（冻结）
    #           Init_Epoch = 0，UnFreeze_Epoch = 300，Freeze_Train = False，optimizer_type = 'sgd'，Init_lr = 1e-2，weight_decay = 5e-4。（不冻结）
    #       其中：由于从主干网络的预训练权重开始训练，主干的权值不一定适合目标检测，需要更多的训练跳出局部最优解。
    #             UnFreeze_Epoch可以在150-300之间调整，YOLOV5和YOLOX均推荐使用300。
    #             Adam相较于SGD收敛的快一些。因此UnFreeze_Epoch理论上可以小一点，但依然推荐更多的Epoch。
    #   （三）batch_size的设置：
    #       在显卡能够接受的范围内，以大为好。显存不足与数据集大小无关，提示显存不足（OOM或者CUDA out of memory）请调小batch_size。
    #       受到BatchNorm层影响，batch_size最小为2，不能为1。
    #       正常情况下Freeze_batch_size建议为Unfreeze_batch_size的1-2倍。不建议设置的差距过大，因为关系到学习率的自动调整。
    #----------------------------------------------------------------------------------------------------------------------------#
    #------------------------------------------------------------------#
    #   冻结阶段训练参数
    #   此时模型的主干被冻结了，特征提取网络不发生改变
    #   占用的显存较小，仅对网络进行微调
    #   Init_Epoch          模型当前开始的训练世代，其值可以大于Freeze_Epoch，如设置：
    #                       Init_Epoch = 60、Freeze_Epoch = 50、UnFreeze_Epoch = 100
    #                       会跳过冻结阶段，直接从60代开始，并调整对应的学习率。
    #                       （断点续练时使用）
    #   Freeze_Epoch        模型冻结训练的Freeze_Epoch
    #                       (当Freeze_Train=False时失效)
    #   Freeze_batch_size   模型冻结训练的batch_size
    #                       (当Freeze_Train=False时失效)
    #------------------------------------------------------------------#
    Init_Epoch          = 0
    Freeze_Epoch        = 50
    Freeze_batch_size   = 2
    #------------------------------------------------------------------#
    #   解冻阶段训练参数
    #   此时模型的主干不被冻结了，特征提取网络会发生改变
    #   占用的显存较大，网络所有的参数都会发生改变
    #   UnFreeze_Epoch          模型总共训练的epoch
    #                           SGD需要更长的时间收敛，因此设置较大的UnFreeze_Epoch
    #                           Adam可以使用相对较小的UnFreeze_Epoch
    #   Unfreeze_batch_size     模型在解冻后的batch_size
    #------------------------------------------------------------------#
    UnFreeze_Epoch      = 300
    Unfreeze_batch_size = 2
    #------------------------------------------------------------------#
    #   Freeze_Train    是否进行冻结训练
    #                   默认先冻结主干训练后解冻训练。
    #------------------------------------------------------------------#
    Freeze_Train        = True

    #------------------------------------------------------------------#
    #   其它训练参数：学习率、优化器、学习率下降有关
    #------------------------------------------------------------------#
    #------------------------------------------------------------------#
    #   Init_lr         模型的最大学习率
    #   Min_lr          模型的最小学习率，默认为最大学习率的0.01
    #------------------------------------------------------------------#
    Init_lr             = 1e-2
    Min_lr              = Init_lr * 0.01
    #------------------------------------------------------------------#
    #   optimizer_type  使用到的优化器种类，可选的有adam、sgd
    #                   当使用Adam优化器时建议设置  Init_lr=1e-3
    #                   当使用SGD优化器时建议设置   Init_lr=1e-2
    #   momentum        优化器内部使用到的momentum参数
    #   weight_decay    权值衰减，可防止过拟合
    #                   adam会导致weight_decay错误，使用adam时建议设置为0。
    #------------------------------------------------------------------#
    optimizer_type      = "sgd"
    momentum            = 0.937
    weight_decay        = 5e-4
    #------------------------------------------------------------------#
    #   lr_decay_type   使用到的学习率下降方式，可选的有step、cos
    #------------------------------------------------------------------#
    lr_decay_type       = "cos"
    #------------------------------------------------------------------#
    #   save_period     多少个epoch保存一次权值
    #------------------------------------------------------------------#
    save_period         = 10
    #------------------------------------------------------------------#
    #   save_dir        权值与日志文件保存的文件夹
    #------------------------------------------------------------------#
    save_dir            = 'logs'
    #------------------------------------------------------------------#
    #   eval_flag       是否在训练时进行评估，评估对象为验证集
    #                   安装pycocotools库后，评估体验更佳。
    #   eval_period     代表多少个epoch评估一次，不建议频繁的评估
    #                   评估需要消耗较多的时间，频繁评估会导致训练非常慢
    #   此处获得的mAP会与get_map.py获得的会有所不同，原因有二：
    #   （一）此处获得的mAP为验证集的mAP。
    #   （二）此处设置评估参数较为保守，目的是加快评估速度。
    #------------------------------------------------------------------#
    eval_flag           = True
    eval_period         = 10
    #------------------------------------------------------------------#
    #   num_workers     用于设置是否使用多线程读取数据
    #                   开启后会加快数据读取速度，但是会占用更多内存
    #                   内存较小的电脑可以设置为2或者0  
    #------------------------------------------------------------------#
    num_workers         = 0

    #----------------------------------------------------#
    #   获得图片路径和标签
    #----------------------------------------------------#
    train_annotation_path   = '2007_train.txt'
    val_annotation_path     = '2007_val.txt'

    seed_everything(seed)
    #------------------------------------------------------#
    #   设置用到的显卡
    #------------------------------------------------------#
    ngpus_per_node  = torch.cuda.device_count()
    if distributed:
        dist.init_process_group(backend="nccl")
        local_rank  = int(os.environ["LOCAL_RANK"])
        rank        = int(os.environ["RANK"])
        device      = torch.device("cuda", local_rank)
        if local_rank == 0:
            print(f"[{os.getpid()}] (rank = {rank}, local_rank = {local_rank}) training...")
            print("Gpu Device Count : ", ngpus_per_node)
    else:
        device          = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        local_rank      = 0
        rank            = 0

    #----------------------------------------------------#
    #   下载预训练权重
    #----------------------------------------------------#
    if pretrained:
        backbone = "efficientnet-b" + str(phi)
        if distributed:
            if local_rank == 0:
                download_weights(backbone)  
            dist.barrier()
        else:
            download_weights(backbone)
        
    #----------------------------------------------------#
    #   获取classes和anchor
    #----------------------------------------------------#
    class_names, num_classes = get_classes(classes_path)
    anchors, num_anchors     = get_anchors(anchors_path)

    #------------------------------------------------------#
    #   创建yolo模型
    #------------------------------------------------------#
    model = YoloBody(anchors_mask, num_classes, phi=phi, load_weights=pretrained)
    if not pretrained:
        weights_init(model)
    if model_path != '':
        #------------------------------------------------------#
        #   权值文件请看README，百度网盘下载
        #------------------------------------------------------#
        if local_rank == 0:
            print('Load weights {}.'.format(model_path))
        
        #------------------------------------------------------#
        #   根据预训练权重的Key和模型的Key进行加载
        #------------------------------------------------------#
        model_dict      = model.state_dict()
        pretrained_dict = torch.load(model_path, map_location = device)
        load_key, no_load_key, temp_dict = [], [], {}
        for k, v in pretrained_dict.items():
            if k in model_dict.keys() and np.shape(model_dict[k]) == np.shape(v):
                temp_dict[k] = v
                load_key.append(k)
            else:
                no_load_key.append(k)
        model_dict.update(temp_dict)
        model.load_state_dict(model_dict)
        #------------------------------------------------------#
        #   显示没有匹配上的Key
        #------------------------------------------------------#
        if local_rank == 0:
            print("\nSuccessful Load Key:", str(load_key)[:500], "……\nSuccessful Load Key Num:", len(load_key))
            print("\nFail To Load Key:", str(no_load_key)[:500], "……\nFail To Load Key num:", len(no_load_key))
            print("\n\033[1;33;44m温馨提示，head部分没有载入是正常现象，Backbone部分没有载入是错误的。\033[0m")

    #----------------------#
    #   获得损失函数
    #----------------------#
    yolo_loss    = YOLOLoss(anchors, num_classes, input_shape, Cuda, anchors_mask)
    #----------------------#
    #   记录Loss
    #----------------------#
    if local_rank == 0:
        time_str        = datetime.datetime.strftime(datetime.datetime.now(),'%Y_%m_%d_%H_%M_%S')
        log_dir         = os.path.join(save_dir, "loss_" + str(time_str))
        loss_history    = LossHistory(log_dir, model, input_shape=input_shape)
    else:
        loss_history    = None
        
    #------------------------------------------------------------------#
    #   torch 1.2不支持amp，建议使用torch 1.7.1及以上正确使用fp16
    #   因此torch1.2这里显示"could not be resolve"
    #------------------------------------------------------------------#
    if fp16:
        from torch.cuda.amp import GradScaler as GradScaler
        scaler = GradScaler()
    else:
        scaler = None

    model_train     = model.train()
    #----------------------------#
    #   多卡同步Bn
    #----------------------------#
    if sync_bn and ngpus_per_node > 1 and distributed:
        model_train = torch.nn.SyncBatchNorm.convert_sync_batchnorm(model_train)
    elif sync_bn:
        print("Sync_bn is not support in one gpu or not distributed.")

    if Cuda:
        if distributed:
            #----------------------------#
            #   多卡平行运行
            #----------------------------#
            model_train = model_train.cuda(local_rank)
            model_train = torch.nn.parallel.DistributedDataParallel(model_train, device_ids=[local_rank], find_unused_parameters=True)
        else:
            model_train = torch.nn.DataParallel(model)
            cudnn.benchmark = True
            model_train = model_train.cuda()

    #---------------------------#
    #   读取数据集对应的txt
    #---------------------------#
    with open(train_annotation_path) as f:
        train_lines = f.readlines()
    with open(val_annotation_path) as f:
        val_lines   = f.readlines()
    num_train   = len(train_lines)
    num_val     = len(val_lines)
    
    if local_rank == 0:
        show_config(
            classes_path = classes_path, anchors_path = anchors_path, anchors_mask = anchors_mask, model_path = model_path, input_shape = input_shape, \
            Init_Epoch = Init_Epoch, Freeze_Epoch = Freeze_Epoch, UnFreeze_Epoch = UnFreeze_Epoch, Freeze_batch_size = Freeze_batch_size, Unfreeze_batch_size = Unfreeze_batch_size, Freeze_Train = Freeze_Train, \
            Init_lr = Init_lr, Min_lr = Min_lr, optimizer_type = optimizer_type, momentum = momentum, lr_decay_type = lr_decay_type, \
            save_period = save_period, save_dir = save_dir, num_workers = num_workers, num_train = num_train, num_val = num_val
        )
        #---------------------------------------------------------#
        #   总训练世代指的是遍历全部数据的总次数
        #   总训练步长指的是梯度下降的总次数 
        #   每个训练世代包含若干训练步长，每个训练步长进行一次梯度下降。
        #   此处仅建议最低训练世代，上不封顶，计算时只考虑了解冻部分
        #----------------------------------------------------------#
        wanted_step = 5e4 if optimizer_type == "sgd" else 1.5e4
        total_step  = num_train // Unfreeze_batch_size * UnFreeze_Epoch
        if total_step <= wanted_step:
            if num_train // Unfreeze_batch_size == 0:
                raise ValueError('数据集过小，无法进行训练，请扩充数据集。')
            wanted_epoch = wanted_step // (num_train // Unfreeze_batch_size) + 1
            print("\n\033[1;33;44m[Warning] 使用%s优化器时，建议将训练总步长设置到%d以上。\033[0m"%(optimizer_type, wanted_step))
            print("\033[1;33;44m[Warning] 本次运行的总训练数据量为%d，Unfreeze_batch_size为%d，共训练%d个Epoch，计算出总训练步长为%d。\033[0m"%(num_train, Unfreeze_batch_size, UnFreeze_Epoch, total_step))
            print("\033[1;33;44m[Warning] 由于总训练步长为%d，小于建议总步长%d，建议设置总世代为%d。\033[0m"%(total_step, wanted_step, wanted_epoch))

    #------------------------------------------------------#
    #   主干特征提取网络特征通用，冻结训练可以加快训练速度
    #   也可以在训练初期防止权值被破坏。
    #   Init_Epoch为起始世代
    #   Freeze_Epoch为冻结训练的世代
    #   UnFreeze_Epoch总训练世代
    #   提示OOM或者显存不足请调小Batch_size
    #------------------------------------------------------#
    if True:
        UnFreeze_flag = False
        #------------------------------------#
        #   冻结一定部分训练
        #------------------------------------#
        if Freeze_Train:
            for param in model.backbone.parameters():
                param.requires_grad = False

        #-------------------------------------------------------------------#
        #   如果不冻结训练的话，直接设置batch_size为Unfreeze_batch_size
        #-------------------------------------------------------------------#
        batch_size = Freeze_batch_size if Freeze_Train else Unfreeze_batch_size

        #-------------------------------------------------------------------#
        #   判断当前batch_size，自适应调整学习率
        #-------------------------------------------------------------------#
        nbs             = 64
        lr_limit_max    = 1e-3 if optimizer_type == 'adam' else 5e-2
        lr_limit_min    = 3e-4 if optimizer_type == 'adam' else 5e-4
        Init_lr_fit     = min(max(batch_size / nbs * Init_lr, lr_limit_min), lr_limit_max)
        Min_lr_fit      = min(max(batch_size / nbs * Min_lr, lr_limit_min * 1e-2), lr_limit_max * 1e-2)

        #---------------------------------------#
        #   根据optimizer_type选择优化器
        #---------------------------------------#
        pg0, pg1, pg2 = [], [], []  
        for k, v in model.named_modules():
            if hasattr(v, "bias") and isinstance(v.bias, nn.Parameter):
                pg2.append(v.bias)    
            if isinstance(v, nn.BatchNorm2d) or "bn" in k:
                pg0.append(v.weight)    
            elif hasattr(v, "weight") and isinstance(v.weight, nn.Parameter):
                pg1.append(v.weight)   
        optimizer = {
            'adam'  : optim.Adam(pg0, Init_lr_fit, betas = (momentum, 0.999)),
            'sgd'   : optim.SGD(pg0, Init_lr_fit, momentum = momentum, nesterov=True)
        }[optimizer_type]
        optimizer.add_param_group({"params": pg1, "weight_decay": weight_decay})
        optimizer.add_param_group({"params": pg2})

        #---------------------------------------#
        #   获得学习率下降的公式
        #---------------------------------------#
        lr_scheduler_func = get_lr_scheduler(lr_decay_type, Init_lr_fit, Min_lr_fit, UnFreeze_Epoch)
        
        #---------------------------------------#
        #   判断每一个世代的长度
        #---------------------------------------#
        epoch_step      = num_train // batch_size
        epoch_step_val  = num_val // batch_size
        
        if epoch_step == 0 or epoch_step_val == 0:
            raise ValueError("数据集过小，无法继续进行训练，请扩充数据集。")

        #---------------------------------------#
        #   构建数据集加载器。
        #---------------------------------------#
        train_dataset   = YoloDataset(train_lines, input_shape, num_classes, train = True)
        val_dataset     = YoloDataset(val_lines, input_shape, num_classes, train = False)
        
        if distributed:
            train_sampler   = torch.utils.data.distributed.DistributedSampler(train_dataset, shuffle=True,)
            val_sampler     = torch.utils.data.distributed.DistributedSampler(val_dataset, shuffle=False,)
            batch_size      = batch_size // ngpus_per_node
            shuffle         = False
        else:
            train_sampler   = None
            val_sampler     = None
            shuffle         = True

        gen             = DataLoader(train_dataset, shuffle = shuffle, batch_size = batch_size, num_workers = num_workers, pin_memory=True,
                                    drop_last=True, collate_fn=yolo_dataset_collate, sampler=train_sampler)
        gen_val         = DataLoader(val_dataset  , shuffle = shuffle, batch_size = batch_size, num_workers = num_workers, pin_memory=True, 
                                    drop_last=True, collate_fn=yolo_dataset_collate, sampler=val_sampler)

        #----------------------#
        #   记录eval的map曲线
        #----------------------#
        if local_rank == 0:
            eval_callback   = EvalCallback(model, input_shape, anchors, anchors_mask, class_names, num_classes, val_lines, log_dir, Cuda, \
                                            eval_flag=eval_flag, period=eval_period)
        else:
            eval_callback   = None
        
        #---------------------------------------#
        #   开始模型训练
        #---------------------------------------#
        for epoch in range(Init_Epoch, UnFreeze_Epoch):
            #---------------------------------------#
            #   如果模型有冻结学习部分
            #   则解冻，并设置参数
            #---------------------------------------#
            if epoch >= Freeze_Epoch and not UnFreeze_flag and Freeze_Train:
                batch_size = Unfreeze_batch_size

                #-------------------------------------------------------------------#
                #   判断当前batch_size，自适应调整学习率
                #-------------------------------------------------------------------#
                nbs             = 64
                lr_limit_max    = 1e-3 if optimizer_type == 'adam' else 5e-2
                lr_limit_min    = 3e-4 if optimizer_type == 'adam' else 5e-4
                Init_lr_fit     = min(max(batch_size / nbs * Init_lr, lr_limit_min), lr_limit_max)
                Min_lr_fit      = min(max(batch_size / nbs * Min_lr, lr_limit_min * 1e-2), lr_limit_max * 1e-2)
                #---------------------------------------#
                #   获得学习率下降的公式
                #---------------------------------------#
                lr_scheduler_func = get_lr_scheduler(lr_decay_type, Init_lr_fit, Min_lr_fit, UnFreeze_Epoch)
                
                for param in model.backbone.parameters():
                    param.requires_grad = True

                epoch_step      = num_train // batch_size
                epoch_step_val  = num_val // batch_size

                if epoch_step == 0 or epoch_step_val == 0:
                    raise ValueError("数据集过小，无法继续进行训练，请扩充数据集。")

                if distributed:
                    batch_size = batch_size // ngpus_per_node
                    
                gen             = DataLoader(train_dataset, shuffle = shuffle, batch_size = batch_size, num_workers = num_workers, pin_memory=True,
                                            drop_last=True, collate_fn=yolo_dataset_collate, sampler=train_sampler, 
                                            worker_init_fn=partial(worker_init_fn, rank=rank, seed=seed))
                gen_val         = DataLoader(val_dataset  , shuffle = shuffle, batch_size = batch_size, num_workers = num_workers, pin_memory=True, 
                                            drop_last=True, collate_fn=yolo_dataset_collate, sampler=val_sampler, 
                                            worker_init_fn=partial(worker_init_fn, rank=rank, seed=seed))

                UnFreeze_flag = True

            if distributed:
                train_sampler.set_epoch(epoch)
                
            set_optimizer_lr(optimizer, lr_scheduler_func, epoch)

            fit_one_epoch(model_train, model, yolo_loss, loss_history, eval_callback, optimizer, epoch, epoch_step, epoch_step_val, gen, gen_val, UnFreeze_Epoch, Cuda, fp16, scaler, save_period, save_dir, local_rank)
                        
            if distributed:
                dist.barrier()

        if local_rank == 0:
            loss_history.writer.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 281
#     276 anchors, num_anchors     = get_anchors(anchors_path)
#     278 #------------------------------------------------------#
#     279 #   创建yolo模型
#     280 #------------------------------------------------------#
# --> 281 model = YoloBody(anchors_mask, num_classes, phi=phi, load_weights=pretrained)
#     282 if not pretrained:
#     283     weights_init(model)
#
# File D:\StudyTool\jupyter-projects\Mdoule\Fire-YOLO\nets\yolo.ipynb:76, in __init__(self, anchors_mask, num_classes, phi, load_weights)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": null,
#       6    "id": "33edd882",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "from collections import OrderedDict\n",
#      11     "\n",
#      12     "import torch\n",
#      13     "import torch.nn as nn\n",
#      14     "\n",
#      15     "from nets.efficientnet import EfficientNet as EffNet\n",
#      16     "\n",
#      17     "\n",
#      18     "class EfficientNet(nn.Module):\n",
#      19     "    def __init__(self, phi, load_weights=False):\n",
#      20     "        super(EfficientNet, self).__init__()\n",
#      21     "        model = EffNet.from_pretrained(f'efficientnet-b{phi}', load_weights)\n",
#      22     "        del model._conv_head\n",
#      23     "        del model._bn1\n",
#      24     "        del model._avg_pooling\n",
#      25     "        del model._dropout\n",
#      26     "        del model._fc\n",
#      27     "        self.model = model\n",
#      28     "\n",
#      29     "    def forward(self, x):\n",
#      30     "        x = self.model._conv_stem(x)\n",
#      31     "        x = self.model._bn0(x)\n",
#      32     "        x = self.model._swish(x)\n",
#      33     "        feature_maps = []\n",
#      34     "\n",
#      35     "        last_x = None\n",
#      36     "        for idx, block in enumerate(self.model._blocks):\n",
#      37     "            drop_connect_rate = self.model._global_params.drop_connect_rate\n",
#      38     "            if drop_connect_rate:\n",
#      39     "                drop_connect_rate *= float(idx) / len(self.model._blocks)\n",
#      40     "            x = block(x, drop_connect_rate=drop_connect_rate)\n",
#      41     "            if block._depthwise_conv.stride == [2, 2]:\n",
#      42     "                feature_maps.append(last_x)\n",
#      43     "            elif idx == len(self.model._blocks) - 1:\n",
#      44     "                feature_maps.append(x)\n",
#      45     "            last_x = x\n",
#      46     "        del last_x\n",
#      47     "        out_feats = [feature_maps[2],feature_maps[3],feature_maps[4]]\n",
#      48     "        return out_feats\n",
#      49     "\n",
#      50     "\n",
#      51     "def conv2d(filter_in, filter_out, kernel_size):\n",
#      52     "    pad = (kernel_size - 1) // 2 if kernel_size else 0\n",
#      53     "    return nn.Sequential(OrderedDict([\n",
#      54     "        (\"conv\", nn.Conv2d(filter_in, filter_out, kernel_size=kernel_size, stride=1, padding=pad, bias=False)),\n",
#      55     "        (\"bn\", nn.BatchNorm2d(filter_out)),\n",
#      56     "        (\"relu\", nn.LeakyReLU(0.1)),\n",
#      57     "    ]))\n",
#      58     "\n",
#      59     "#------------------------------------------------------------------------#\n",
#      60     "#   make_last_layers里面一共有七个卷积，前五个用于提取特征。\n",
#      61     "#   后两个用于获得yolo网络的预测结果\n",
#      62     "#------------------------------------------------------------------------#\n",
#      63     "def make_last_layers(filters_list, in_filters, out_filter):\n",
#      64     "    m = nn.Sequential(\n",
#      65     "        conv2d(in_filters, filters_list[0], 1),\n",
#      66     "        conv2d(filters_list[0], filters_list[1], 3),\n",
#      67     "        conv2d(filters_list[1], filters_list[0], 1),\n",
#      68     "        conv2d(filters_list[0], filters_list[1], 3),\n",
#      69     "        conv2d(filters_list[1], filters_list[0], 1),\n",
#      70     "        conv2d(filters_list[0], filters_list[1], 3),\n",
#      71     "        nn.Conv2d(filters_list[1], out_filter, kernel_size=1, stride=1, padding=0, bias=True)\n",
#      72     "    )\n",
#      73     "    return m\n",
#      74     "\n",
#      75     "class YoloBody(nn.Module):\n",
# ---> 76     "    def __init__(self, anchors_mask, num_classes, phi=0, load_weights = False):\n",
#      77     "        super(YoloBody, self).__init__()\n",
#      78     "        #---------------------------------------------------#   \n",
#      79     "        #   生成efficientnet的主干模型，以efficientnetB0为例\n",
#      80     "        #   获得三个有效特征层，他们的shape分别是：\n",
#      81     "        #   52, 52, 40\n",
#      82     "        #   26, 26, 112\n",
#      83     "        #   13, 13, 320\n",
#      84     "        #---------------------------------------------------#\n",
#      85     "        self.backbone = EfficientNet(phi, load_weights = load_weights)\n",
#      86     "\n",
#      87     "        out_filters = {\n",
#      88     "            0: [40, 112, 320],\n",
#      89     "            1: [40, 112, 320],\n",
#      90     "            2: [48, 120, 352],\n",
#      91     "            3: [48, 136, 384],\n",
#      92     "            4: [56, 160, 448],\n",
#      93     "            5: [64, 176, 512],\n",
#      94     "            6: [72, 200, 576],\n",
#      95     "            7: [80, 224, 640],\n",
#      96     "        }[phi]\n",
#      97     "\n",
#      98     "        self.last_layer0            = make_last_layers([out_filters[-1], int(out_filters[-1]*2)], out_filters[-1], len(anchors_mask[0]) * (num_classes + 5))\n",
#      99     "\n",
#     100     "        self.last_layer1_conv       = conv2d(out_filters[-1], out_filters[-2], 1)\n",
#     101     "        self.last_layer1_upsample   = nn.Upsample(scale_factor=2, mode='nearest')\n",
#     102     "        self.last_layer1            = make_last_layers([out_filters[-2], int(out_filters[-2]*2)], out_filters[-2] + out_filters[-2], len(anchors_mask[1]) * (num_classes + 5))\n",
#     103     "\n",
#     104     "        self.last_layer2_conv       = conv2d(out_filters[-2], out_filters[-3], 1)\n",
#     105     "        self.last_layer2_upsample   = nn.Upsample(scale_factor=2, mode='nearest')\n",
#     106     "        self.last_layer2            = make_last_layers([out_filters[-3], int(out_filters[-3]*2)], out_filters[-3] + out_filters[-3], len(anchors_mask[2]) * (num_classes + 5))\n",
#     107     "\n",
#     108     "    def forward(self, x):\n",
#     109     "        #---------------------------------------------------#   \n",
#     110     "        #   获得三个有效特征层，他们的shape分别是：\n",
#     111     "        #   52, 52, 40\n",
#     112     "        #   26, 26, 112\n",
#     113     "        #   13, 13, 320\n",
#     114     "        #---------------------------------------------------#\n",
#     115     "        x2, x1, x0 = self.backbone(x)\n",
#     116     "\n",
#     117     "        #---------------------------------------------------#\n",
#     118     "        #   第一个特征层\n",
#     119     "        #   out0 = (batch_size,255,13,13)\n",
#     120     "        #---------------------------------------------------#\n",
#     121     "        out0_branch = self.last_layer0[:5](x0)\n",
#     122     "        out0        = self.last_layer0[5:](out0_branch)\n",
#     123     "\n",
#     124     "        x1_in = self.last_layer1_conv(out0_branch)\n",
#     125     "        x1_in = self.last_layer1_upsample(x1_in)\n",
#     126     "\n",
#     127     "        x1_in = torch.cat([x1_in, x1], 1)\n",
#     128     "        #---------------------------------------------------#\n",
#     129     "        #   第二个特征层\n",
#     130     "        #   out1 = (batch_size,255,26,26)\n",
#     131     "        #---------------------------------------------------#\n",
#     132     "        out1_branch = self.last_layer1[:5](x1_in)\n",
#     133     "        out1        = self.last_layer1[5:](out1_branch)\n",
#     134     "\n",
#     135     "        x2_in = self.last_layer2_conv(out1_branch)\n",
#     136     "        x2_in = self.last_layer2_upsample(x2_in)\n",
#     137     "\n",
#     138     "        x2_in = torch.cat([x2_in, x2], 1)\n",
#     139     "        #---------------------------------------------------#\n",
#     140     "        #   第一个特征层\n",
#     141     "        #   out3 = (batch_size,255,52,52)\n",
#     142     "        #---------------------------------------------------#\n",
#     143     "        out2 = self.last_layer2(x2_in)\n",
#     144     "        return out0, out1, out2\n",
#     145     "\n"
#     146    ]
#     147   }
#     148  ],
#     149  "metadata": {
#     150   "kernelspec": {
#     151    "display_name": "torch[python3.9]",
#     152    "language": "python",
#     153    "name": "pytorchuse"
#     154   },
#     155   "language_info": {
#     156    "codemirror_mode": {
#     157     "name": "ipython",
#     158     "version": 3
#     159    },
#     160    "file_extension": ".py",
#     161    "mimetype": "text/x-python",
#     162    "name": "python",
#     163    "nbconvert_exporter": "python",
#     164    "pygments_lexer": "ipython3",
#     165    "version": "3.9.19"
#     166   }
#     167  },
#     168  "nbformat": 4,
#     169  "nbformat_minor": 5
#     170 }
#
# File D:\StudyTool\jupyter-projects\Mdoule\Fire-YOLO\nets\yolo.ipynb:12, in __init__(self, phi, load_weights)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": null,
#       6    "id": "33edd882",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "from collections import OrderedDict\n",
#      11     "\n",
# ---> 12     "import torch\n",
#      13     "import torch.nn as nn\n",
#      14     "\n",
#      15     "from nets.efficientnet import EfficientNet as EffNet\n",
#      16     "\n",
#      17     "\n",
#      18     "class EfficientNet(nn.Module):\n",
#      19     "    def __init__(self, phi, load_weights=False):\n",
#      20     "        super(EfficientNet, self).__init__()\n",
#      21     "        model = EffNet.from_pretrained(f'efficientnet-b{phi}', load_weights)\n",
#      22     "        del model._conv_head\n",
#      23     "        del model._bn1\n",
#      24     "        del model._avg_pooling\n",
#      25     "        del model._dropout\n",
#      26     "        del model._fc\n",
#      27     "        self.model = model\n",
#      28     "\n",
#      29     "    def forward(self, x):\n",
#      30     "        x = self.model._conv_stem(x)\n",
#      31     "        x = self.model._bn0(x)\n",
#      32     "        x = self.model._swish(x)\n",
#      33     "        feature_maps = []\n",
#      34     "\n",
#      35     "        last_x = None\n",
#      36     "        for idx, block in enumerate(self.model._blocks):\n",
#      37     "            drop_connect_rate = self.model._global_params.drop_connect_rate\n",
#      38     "            if drop_connect_rate:\n",
#      39     "                drop_connect_rate *= float(idx) / len(self.model._blocks)\n",
#      40     "            x = block(x, drop_connect_rate=drop_connect_rate)\n",
#      41     "            if block._depthwise_conv.stride == [2, 2]:\n",
#      42     "                feature_maps.append(last_x)\n",
#      43     "            elif idx == len(self.model._blocks) - 1:\n",
#      44     "                feature_maps.append(x)\n",
#      45     "            last_x = x\n",
#      46     "        del last_x\n",
#      47     "        out_feats = [feature_maps[2],feature_maps[3],feature_maps[4]]\n",
#      48     "        return out_feats\n",
#      49     "\n",
#      50     "\n",
#      51     "def conv2d(filter_in, filter_out, kernel_size):\n",
#      52     "    pad = (kernel_size - 1) // 2 if kernel_size else 0\n",
#      53     "    return nn.Sequential(OrderedDict([\n",
#      54     "        (\"conv\", nn.Conv2d(filter_in, filter_out, kernel_size=kernel_size, stride=1, padding=pad, bias=False)),\n",
#      55     "        (\"bn\", nn.BatchNorm2d(filter_out)),\n",
#      56     "        (\"relu\", nn.LeakyReLU(0.1)),\n",
#      57     "    ]))\n",
#      58     "\n",
#      59     "#------------------------------------------------------------------------#\n",
#      60     "#   make_last_layers里面一共有七个卷积，前五个用于提取特征。\n",
#      61     "#   后两个用于获得yolo网络的预测结果\n",
#      62     "#------------------------------------------------------------------------#\n",
#      63     "def make_last_layers(filters_list, in_filters, out_filter):\n",
#      64     "    m = nn.Sequential(\n",
#      65     "        conv2d(in_filters, filters_list[0], 1),\n",
#      66     "        conv2d(filters_list[0], filters_list[1], 3),\n",
#      67     "        conv2d(filters_list[1], filters_list[0], 1),\n",
#      68     "        conv2d(filters_list[0], filters_list[1], 3),\n",
#      69     "        conv2d(filters_list[1], filters_list[0], 1),\n",
#      70     "        conv2d(filters_list[0], filters_list[1], 3),\n",
#      71     "        nn.Conv2d(filters_list[1], out_filter, kernel_size=1, stride=1, padding=0, bias=True)\n",
#      72     "    )\n",
#      73     "    return m\n",
#      74     "\n",
#      75     "class YoloBody(nn.Module):\n",
#      76     "    def __init__(self, anchors_mask, num_classes, phi=0, load_weights = False):\n",
#      77     "        super(YoloBody, self).__init__()\n",
#      78     "        #---------------------------------------------------#   \n",
#      79     "        #   生成efficientnet的主干模型，以efficientnetB0为例\n",
#      80     "        #   获得三个有效特征层，他们的shape分别是：\n",
#      81     "        #   52, 52, 40\n",
#      82     "        #   26, 26, 112\n",
#      83     "        #   13, 13, 320\n",
#      84     "        #---------------------------------------------------#\n",
#      85     "        self.backbone = EfficientNet(phi, load_weights = load_weights)\n",
#      86     "\n",
#      87     "        out_filters = {\n",
#      88     "            0: [40, 112, 320],\n",
#      89     "            1: [40, 112, 320],\n",
#      90     "            2: [48, 120, 352],\n",
#      91     "            3: [48, 136, 384],\n",
#      92     "            4: [56, 160, 448],\n",
#      93     "            5: [64, 176, 512],\n",
#      94     "            6: [72, 200, 576],\n",
#      95     "            7: [80, 224, 640],\n",
#      96     "        }[phi]\n",
#      97     "\n",
#      98     "        self.last_layer0            = make_last_layers([out_filters[-1], int(out_filters[-1]*2)], out_filters[-1], len(anchors_mask[0]) * (num_classes + 5))\n",
#      99     "\n",
#     100     "        self.last_layer1_conv       = conv2d(out_filters[-1], out_filters[-2], 1)\n",
#     101     "        self.last_layer1_upsample   = nn.Upsample(scale_factor=2, mode='nearest')\n",
#     102     "        self.last_layer1            = make_last_layers([out_filters[-2], int(out_filters[-2]*2)], out_filters[-2] + out_filters[-2], len(anchors_mask[1]) * (num_classes + 5))\n",
#     103     "\n",
#     104     "        self.last_layer2_conv       = conv2d(out_filters[-2], out_filters[-3], 1)\n",
#     105     "        self.last_layer2_upsample   = nn.Upsample(scale_factor=2, mode='nearest')\n",
#     106     "        self.last_layer2            = make_last_layers([out_filters[-3], int(out_filters[-3]*2)], out_filters[-3] + out_filters[-3], len(anchors_mask[2]) * (num_classes + 5))\n",
#     107     "\n",
#     108     "    def forward(self, x):\n",
#     109     "        #---------------------------------------------------#   \n",
#     110     "        #   获得三个有效特征层，他们的shape分别是：\n",
#     111     "        #   52, 52, 40\n",
#     112     "        #   26, 26, 112\n",
#     113     "        #   13, 13, 320\n",
#     114     "        #---------------------------------------------------#\n",
#     115     "        x2, x1, x0 = self.backbone(x)\n",
#     116     "\n",
#     117     "        #---------------------------------------------------#\n",
#     118     "        #   第一个特征层\n",
#     119     "        #   out0 = (batch_size,255,13,13)\n",
#     120     "        #---------------------------------------------------#\n",
#     121     "        out0_branch = self.last_layer0[:5](x0)\n",
#     122     "        out0        = self.last_layer0[5:](out0_branch)\n",
#     123     "\n",
#     124     "        x1_in = self.last_layer1_conv(out0_branch)\n",
#     125     "        x1_in = self.last_layer1_upsample(x1_in)\n",
#     126     "\n",
#     127     "        x1_in = torch.cat([x1_in, x1], 1)\n",
#     128     "        #---------------------------------------------------#\n",
#     129     "        #   第二个特征层\n",
#     130     "        #   out1 = (batch_size,255,26,26)\n",
#     131     "        #---------------------------------------------------#\n",
#     132     "        out1_branch = self.last_layer1[:5](x1_in)\n",
#     133     "        out1        = self.last_layer1[5:](out1_branch)\n",
#     134     "\n",
#     135     "        x2_in = self.last_layer2_conv(out1_branch)\n",
#     136     "        x2_in = self.last_layer2_upsample(x2_in)\n",
#     137     "\n",
#     138     "        x2_in = torch.cat([x2_in, x2], 1)\n",
#     139     "        #---------------------------------------------------#\n",
#     140     "        #   第一个特征层\n",
#     141     "        #   out3 = (batch_size,255,52,52)\n",
#     142     "        #---------------------------------------------------#\n",
#     143     "        out2 = self.last_layer2(x2_in)\n",
#     144     "        return out0, out1, out2\n",
#     145     "\n"
#     146    ]
#     147   }
#     148  ],
#     149  "metadata": {
#     150   "kernelspec": {
#     151    "display_name": "torch[python3.9]",
#     152    "language": "python",
#     153    "name": "pytorchuse"
#     154   },
#     155   "language_info": {
#     156    "codemirror_mode": {
#     157     "name": "ipython",
#     158     "version": 3
#     159    },
#     160    "file_extension": ".py",
#     161    "mimetype": "text/x-python",
#     162    "name": "python",
#     163    "nbconvert_exporter": "python",
#     164    "pygments_lexer": "ipython3",
#     165    "version": "3.9.19"
#     166   }
#     167  },
#     168  "nbformat": 4,
#     169  "nbformat_minor": 5
#     170 }
#
# File D:\StudyTool\jupyter-projects\Mdoule\Fire-YOLO\nets\efficientnet.ipynb:560, in from_pretrained(cls, model_name, load_weights, advprop, num_classes, in_channels)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": null,
#       6    "id": "6eae09a5",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import collections\n",
#      11     "import math\n",
#      12     "import re\n",
#      13     "from functools import partial\n",
#      14     "\n",
#      15     "import torch\n",
#      16     "from torch import nn\n",
#      17     "from torch.nn import functional as F\n",
#      18     "from torch.utils import model_zoo\n",
#      19     "\n",
#      20     "########################################################################\n",
#      21     "############### HELPERS FUNCTIONS FOR MODEL ARCHITECTURE ###############\n",
#      22     "########################################################################\n",
#      23     "\n",
#      24     "\n",
#      25     "# Parameters for the entire model (stem, all blocks, and head)\n",
#      26     "GlobalParams = collections.namedtuple('GlobalParams', [\n",
#      27     "    'batch_norm_momentum', 'batch_norm_epsilon', 'dropout_rate',\n",
#      28     "    'num_classes', 'width_coefficient', 'depth_coefficient',\n",
#      29     "    'depth_divisor', 'min_depth', 'drop_connect_rate', 'image_size'])\n",
#      30     "\n",
#      31     "# Parameters for an individual model block\n",
#      32     "BlockArgs = collections.namedtuple('BlockArgs', [\n",
#      33     "    'kernel_size', 'num_repeat', 'input_filters', 'output_filters',\n",
#      34     "    'expand_ratio', 'id_skip', 'stride', 'se_ratio'])\n",
#      35     "\n",
#      36     "# Change namedtuple defaults\n",
#      37     "GlobalParams.__new__.__defaults__ = (None,) * len(GlobalParams._fields)\n",
#      38     "BlockArgs.__new__.__defaults__ = (None,) * len(BlockArgs._fields)\n",
#      39     "\n",
#      40     "\n",
#      41     "class SwishImplementation(torch.autograd.Function):\n",
#      42     "    @staticmethod\n",
#      43     "    def forward(ctx, i):\n",
#      44     "        result = i * torch.sigmoid(i)\n",
#      45     "        ctx.save_for_backward(i)\n",
#      46     "        return result\n",
#      47     "\n",
#      48     "    @staticmethod\n",
#      49     "    def backward(ctx, grad_output):\n",
#      50     "        i = ctx.saved_variables[0]\n",
#      51     "        sigmoid_i = torch.sigmoid(i)\n",
#      52     "        return grad_output * (sigmoid_i * (1 + i * (1 - sigmoid_i)))\n",
#      53     "\n",
#      54     "\n",
#      55     "class MemoryEfficientSwish(nn.Module):\n",
#      56     "    def forward(self, x):\n",
#      57     "        return SwishImplementation.apply(x)\n",
#      58     "\n",
#      59     "class Swish(nn.Module):\n",
#      60     "    def forward(self, x):\n",
#      61     "        return x * torch.sigmoid(x)\n",
#      62     "\n",
#      63     "\n",
#      64     "def round_filters(filters, global_params):\n",
#      65     "    \"\"\" Calculate and round number of filters based on depth multiplier. \"\"\"\n",
#      66     "    multiplier = global_params.width_coefficient\n",
#      67     "    if not multiplier:\n",
#      68     "        return filters\n",
#      69     "    divisor = global_params.depth_divisor\n",
#      70     "    min_depth = global_params.min_depth\n",
#      71     "    filters *= multiplier\n",
#      72     "    min_depth = min_depth or divisor\n",
#      73     "    new_filters = max(min_depth, int(filters + divisor / 2) // divisor * divisor)\n",
#      74     "    if new_filters < 0.9 * filters:  # prevent rounding by more than 10%\n",
#      75     "        new_filters += divisor\n",
#      76     "    return int(new_filters)\n",
#      77     "\n",
#      78     "\n",
#      79     "def round_repeats(repeats, global_params):\n",
#      80     "    \"\"\" Round number of filters based on depth multiplier. \"\"\"\n",
#      81     "    multiplier = global_params.depth_coefficient\n",
#      82     "    if not multiplier:\n",
#      83     "        return repeats\n",
#      84     "    return int(math.ceil(multiplier * repeats))\n",
#      85     "\n",
#      86     "\n",
#      87     "def drop_connect(inputs, p, training):\n",
#      88     "    \"\"\" Drop connect. \"\"\"\n",
#      89     "    if not training: return inputs\n",
#      90     "    batch_size = inputs.shape[0]\n",
#      91     "    keep_prob = 1 - p\n",
#      92     "    random_tensor = keep_prob\n",
#      93     "    random_tensor += torch.rand([batch_size, 1, 1, 1], dtype=inputs.dtype, device=inputs.device)\n",
#      94     "    binary_tensor = torch.floor(random_tensor)\n",
#      95     "    output = inputs / keep_prob * binary_tensor\n",
#      96     "    return output\n",
#      97     "\n",
#      98     "\n",
#      99     "def get_same_padding_conv2d(image_size=None):\n",
#     100     "    \"\"\" Chooses static padding if you have specified an image size, and dynamic padding otherwise.\n",
#     101     "        Static padding is necessary for ONNX exporting of models. \"\"\"\n",
#     102     "    if image_size is None:\n",
#     103     "        return Conv2dDynamicSamePadding\n",
#     104     "    else:\n",
#     105     "        return partial(Conv2dStaticSamePadding, image_size=image_size)\n",
#     106     "\n",
#     107     "\n",
#     108     "class Conv2dDynamicSamePadding(nn.Conv2d):\n",
#     109     "    \"\"\" 2D Convolutions like TensorFlow, for a dynamic image size \"\"\"\n",
#     110     "\n",
#     111     "    def __init__(self, in_channels, out_channels, kernel_size, stride=1, dilation=1, groups=1, bias=True):\n",
#     112     "        super().__init__(in_channels, out_channels, kernel_size, stride, 0, dilation, groups, bias)\n",
#     113     "        self.stride = self.stride if len(self.stride) == 2 else [self.stride[0]] * 2\n",
#     114     "\n",
#     115     "    def forward(self, x):\n",
#     116     "        ih, iw = x.size()[-2:]\n",
#     117     "        kh, kw = self.weight.size()[-2:]\n",
#     118     "        sh, sw = self.stride\n",
#     119     "        oh, ow = math.ceil(ih / sh), math.ceil(iw / sw)\n",
#     120     "        pad_h = max((oh - 1) * self.stride[0] + (kh - 1) * self.dilation[0] + 1 - ih, 0)\n",
#     121     "        pad_w = max((ow - 1) * self.stride[1] + (kw - 1) * self.dilation[1] + 1 - iw, 0)\n",
#     122     "        if pad_h > 0 or pad_w > 0:\n",
#     123     "            x = F.pad(x, [pad_w // 2, pad_w - pad_w // 2, pad_h // 2, pad_h - pad_h // 2])\n",
#     124     "        return F.conv2d(x, self.weight, self.bias, self.stride, self.padding, self.dilation, self.groups)\n",
#     125     "\n",
#     126     "\n",
#     127     "class Conv2dStaticSamePadding(nn.Conv2d):\n",
#     128     "    \"\"\" 2D Convolutions like TensorFlow, for a fixed image size\"\"\"\n",
#     129     "\n",
#     130     "    def __init__(self, in_channels, out_channels, kernel_size, image_size=None, **kwargs):\n",
#     131     "        super().__init__(in_channels, out_channels, kernel_size, **kwargs)\n",
#     132     "        self.stride = self.stride if len(self.stride) == 2 else [self.stride[0]] * 2\n",
#     133     "\n",
#     134     "        # Calculate padding based on image size and save it\n",
#     135     "        assert image_size is not None\n",
#     136     "        ih, iw = image_size if type(image_size) == list else [image_size, image_size]\n",
#     137     "        kh, kw = self.weight.size()[-2:]\n",
#     138     "        sh, sw = self.stride\n",
#     139     "        oh, ow = math.ceil(ih / sh), math.ceil(iw / sw)\n",
#     140     "        pad_h = max((oh - 1) * self.stride[0] + (kh - 1) * self.dilation[0] + 1 - ih, 0)\n",
#     141     "        pad_w = max((ow - 1) * self.stride[1] + (kw - 1) * self.dilation[1] + 1 - iw, 0)\n",
#     142     "        if pad_h > 0 or pad_w > 0:\n",
#     143     "            self.static_padding = nn.ZeroPad2d((pad_w // 2, pad_w - pad_w // 2, pad_h // 2, pad_h - pad_h // 2))\n",
#     144     "        else:\n",
#     145     "            self.static_padding = Identity()\n",
#     146     "\n",
#     147     "    def forward(self, x):\n",
#     148     "        x = self.static_padding(x)\n",
#     149     "        x = F.conv2d(x, self.weight, self.bias, self.stride, self.padding, self.dilation, self.groups)\n",
#     150     "        return x\n",
#     151     "\n",
#     152     "\n",
#     153     "class Identity(nn.Module):\n",
#     154     "    def __init__(self, ):\n",
#     155     "        super(Identity, self).__init__()\n",
#     156     "\n",
#     157     "    def forward(self, input):\n",
#     158     "        return input\n",
#     159     "\n",
#     160     "\n",
#     161     "########################################################################\n",
#     162     "############## HELPERS FUNCTIONS FOR LOADING MODEL PARAMS ##############\n",
#     163     "########################################################################\n",
#     164     "\n",
#     165     "\n",
#     166     "def efficientnet_params(model_name):\n",
#     167     "    \"\"\" Map EfficientNet model name to parameter coefficients. \"\"\"\n",
#     168     "    params_dict = {\n",
#     169     "        # Coefficients:   width,depth,res,dropout\n",
#     170     "        'efficientnet-b0': (1.0, 1.0, 224, 0.2),\n",
#     171     "        'efficientnet-b1': (1.0, 1.1, 240, 0.2),\n",
#     172     "        'efficientnet-b2': (1.1, 1.2, 260, 0.3),\n",
#     173     "        'efficientnet-b3': (1.2, 1.4, 300, 0.3),\n",
#     174     "        'efficientnet-b4': (1.4, 1.8, 380, 0.4),\n",
#     175     "        'efficientnet-b5': (1.6, 2.2, 456, 0.4),\n",
#     176     "        'efficientnet-b6': (1.8, 2.6, 528, 0.5),\n",
#     177     "        'efficientnet-b7': (2.0, 3.1, 600, 0.5),\n",
#     178     "        'efficientnet-b8': (2.2, 3.6, 672, 0.5),\n",
#     179     "        'efficientnet-l2': (4.3, 5.3, 800, 0.5),\n",
#     180     "    }\n",
#     181     "    return params_dict[model_name]\n",
#     182     "\n",
#     183     "\n",
#     184     "class BlockDecoder(object):\n",
#     185     "    \"\"\" Block Decoder for readability, straight from the official TensorFlow repository \"\"\"\n",
#     186     "\n",
#     187     "    @staticmethod\n",
#     188     "    def _decode_block_string(block_string):\n",
#     189     "        \"\"\" Gets a block through a string notation of arguments. \"\"\"\n",
#     190     "        assert isinstance(block_string, str)\n",
#     191     "\n",
#     192     "        ops = block_string.split('_')\n",
#     193     "        options = {}\n",
#     194     "        for op in ops:\n",
#     195     "            splits = re.split(r'(\\d.*)', op)\n",
#     196     "            if len(splits) >= 2:\n",
#     197     "                key, value = splits[:2]\n",
#     198     "                options[key] = value\n",
#     199     "\n",
#     200     "        # Check stride\n",
#     201     "        assert (('s' in options and len(options['s']) == 1) or\n",
#     202     "                (len(options['s']) == 2 and options['s'][0] == options['s'][1]))\n",
#     203     "\n",
#     204     "        return BlockArgs(\n",
#     205     "            kernel_size=int(options['k']),\n",
#     206     "            num_repeat=int(options['r']),\n",
#     207     "            input_filters=int(options['i']),\n",
#     208     "            output_filters=int(options['o']),\n",
#     209     "            expand_ratio=int(options['e']),\n",
#     210     "            id_skip=('noskip' not in block_string),\n",
#     211     "            se_ratio=float(options['se']) if 'se' in options else None,\n",
#     212     "            stride=[int(options['s'][0])])\n",
#     213     "\n",
#     214     "    @staticmethod\n",
#     215     "    def _encode_block_string(block):\n",
#     216     "        \"\"\"Encodes a block to a string.\"\"\"\n",
#     217     "        args = [\n",
#     218     "            'r%d' % block.num_repeat,\n",
#     219     "            'k%d' % block.kernel_size,\n",
#     220     "            's%d%d' % (block.strides[0], block.strides[1]),\n",
#     221     "            'e%s' % block.expand_ratio,\n",
#     222     "            'i%d' % block.input_filters,\n",
#     223     "            'o%d' % block.output_filters\n",
#     224     "        ]\n",
#     225     "        if 0 < block.se_ratio <= 1:\n",
#     226     "            args.append('se%s' % block.se_ratio)\n",
#     227     "        if block.id_skip is False:\n",
#     228     "            args.append('noskip')\n",
#     229     "        return '_'.join(args)\n",
#     230     "\n",
#     231     "    @staticmethod\n",
#     232     "    def decode(string_list):\n",
#     233     "        \"\"\"\n",
#     234     "        Decodes a list of string notations to specify blocks inside the network.\n",
#     235     "\n",
#     236     "        :param string_list: a list of strings, each string is a notation of block\n",
#     237     "        :return: a list of BlockArgs namedtuples of block args\n",
#     238     "        \"\"\"\n",
#     239     "        assert isinstance(string_list, list)\n",
#     240     "        blocks_args = []\n",
#     241     "        for block_string in string_list:\n",
#     242     "            blocks_args.append(BlockDecoder._decode_block_string(block_string))\n",
#     243     "        return blocks_args\n",
#     244     "\n",
#     245     "    @staticmethod\n",
#     246     "    def encode(blocks_args):\n",
#     247     "        \"\"\"\n",
#     248     "        Encodes a list of BlockArgs to a list of strings.\n",
#     249     "\n",
#     250     "        :param blocks_args: a list of BlockArgs namedtuples of block args\n",
#     251     "        :return: a list of strings, each string is a notation of block\n",
#     252     "        \"\"\"\n",
#     253     "        block_strings = []\n",
#     254     "        for block in blocks_args:\n",
#     255     "            block_strings.append(BlockDecoder._encode_block_string(block))\n",
#     256     "        return block_strings\n",
#     257     "\n",
#     258     "\n",
#     259     "def efficientnet(width_coefficient=None, depth_coefficient=None, dropout_rate=0.2,\n",
#     260     "                 drop_connect_rate=0.2, image_size=None, num_classes=1000):\n",
#     261     "    \"\"\" Creates a efficientnet model. \"\"\"\n",
#     262     "\n",
#     263     "    blocks_args = [\n",
#     264     "        'r1_k3_s11_e1_i32_o16_se0.25', 'r2_k3_s22_e6_i16_o24_se0.25',\n",
#     265     "        'r2_k5_s22_e6_i24_o40_se0.25', 'r3_k3_s22_e6_i40_o80_se0.25',\n",
#     266     "        'r3_k5_s11_e6_i80_o112_se0.25', 'r4_k5_s22_e6_i112_o192_se0.25',\n",
#     267     "        'r1_k3_s11_e6_i192_o320_se0.25',\n",
#     268     "    ]\n",
#     269     "    blocks_args = BlockDecoder.decode(blocks_args)\n",
#     270     "\n",
#     271     "    global_params = GlobalParams(\n",
#     272     "        batch_norm_momentum=0.99,\n",
#     273     "        batch_norm_epsilon=1e-3,\n",
#     274     "        dropout_rate=dropout_rate,\n",
#     275     "        drop_connect_rate=drop_connect_rate,\n",
#     276     "        # data_format='channels_last',  # removed, this is always true in PyTorch\n",
#     277     "        num_classes=num_classes,\n",
#     278     "        width_coefficient=width_coefficient,\n",
#     279     "        depth_coefficient=depth_coefficient,\n",
#     280     "        depth_divisor=8,\n",
#     281     "        min_depth=None,\n",
#     282     "        image_size=image_size,\n",
#     283     "    )\n",
#     284     "\n",
#     285     "    return blocks_args, global_params\n",
#     286     "\n",
#     287     "\n",
#     288     "def get_model_params(model_name, override_params):\n",
#     289     "    \"\"\" Get the block args and global params for a given model \"\"\"\n",
#     290     "    if model_name.startswith('efficientnet'):\n",
#     291     "        w, d, s, p = efficientnet_params(model_name)\n",
#     292     "        # note: all models have drop connect rate = 0.2\n",
#     293     "        blocks_args, global_params = efficientnet(\n",
#     294     "            width_coefficient=w, depth_coefficient=d, dropout_rate=p, image_size=s)\n",
#     295     "    else:\n",
#     296     "        raise NotImplementedError('model name is not pre-defined: %s' % model_name)\n",
#     297     "    if override_params:\n",
#     298     "        # ValueError will be raised here if override_params has fields not included in global_params.\n",
#     299     "        global_params = global_params._replace(**override_params)\n",
#     300     "    return blocks_args, global_params\n",
#     301     "\n",
#     302     "\n",
#     303     "url_map = {\n",
#     304     "    'efficientnet-b0': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth',\n",
#     305     "    'efficientnet-b1': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b1-f1951068.pth',\n",
#     306     "    'efficientnet-b2': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b2-8bb594d6.pth',\n",
#     307     "    'efficientnet-b3': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b3-5fb5a3c3.pth',\n",
#     308     "    'efficientnet-b4': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b4-6ed6700e.pth',\n",
#     309     "    'efficientnet-b5': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b5-b6417697.pth',\n",
#     310     "    'efficientnet-b6': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b6-c76e70fd.pth',\n",
#     311     "    'efficientnet-b7': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b7-dcc49843.pth',\n",
#     312     "}\n",
#     313     "\n",
#     314     "\n",
#     315     "url_map_advprop = {\n",
#     316     "    'efficientnet-b0': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/adv-efficientnet-b0-b64d5a18.pth',\n",
#     317     "    'efficientnet-b1': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/adv-efficientnet-b1-0f3ce85a.pth',\n",
#     318     "    'efficientnet-b2': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/adv-efficientnet-b2-6e9d97e5.pth',\n",
#     319     "    'efficientnet-b3': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/adv-efficientnet-b3-cdd7c0f4.pth',\n",
#     320     "    'efficientnet-b4': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/adv-efficientnet-b4-44fb3a87.pth',\n",
#     321     "    'efficientnet-b5': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/adv-efficientnet-b5-86493f6b.pth',\n",
#     322     "    'efficientnet-b6': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/adv-efficientnet-b6-ac80338e.pth',\n",
#     323     "    'efficientnet-b7': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/adv-efficientnet-b7-4652b6dd.pth',\n",
#     324     "    'efficientnet-b8': 'https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/adv-efficientnet-b8-22a8fe65.pth',\n",
#     325     "}\n",
#     326     "\n",
#     327     "\n",
#     328     "def load_pretrained_weights(model, model_name, load_fc=True, advprop=False):\n",
#     329     "    \"\"\" Loads pretrained weights, and downloads if loading for the first time. \"\"\"\n",
#     330     "    # AutoAugment or Advprop (different preprocessing)\n",
#     331     "    url_map_ = url_map_advprop if advprop else url_map\n",
#     332     "    state_dict = model_zoo.load_url(url_map_[model_name], model_dir=\"model_data\")\n",
#     333     "    if load_fc:\n",
#     334     "        model.load_state_dict(state_dict, strict=True)\n",
#     335     "        \n",
#     336     "    else:\n",
#     337     "        state_dict.pop('_fc.weight')\n",
#     338     "        state_dict.pop('_fc.bias')\n",
#     339     "        res = model.load_state_dict(state_dict, strict=False)\n",
#     340     "        assert set(res.missing_keys) == set(['_fc.weight', '_fc.bias']), 'issue loading pretrained weights'\n",
#     341     "    print('Loaded pretrained weights for {}'.format(model_name))\n",
#     342     "\n",
#     343     "\n",
#     344     "class MBConvBlock(nn.Module):\n",
#     345     "    '''\n",
#     346     "    EfficientNet-b0:\n",
#     347     "    [BlockArgs(kernel_size=3, num_repeat=1, input_filters=32, output_filters=16, expand_ratio=1, id_skip=True, stride=[1], se_ratio=0.25), \n",
#     348     "\n",
#     349     "     BlockArgs(kernel_size=3, num_repeat=2, input_filters=16, output_filters=24, expand_ratio=6, id_skip=True, stride=[2], se_ratio=0.25), \n",
#     350     "\n",
#     351     "     BlockArgs(kernel_size=5, num_repeat=2, input_filters=24, output_filters=40, expand_ratio=6, id_skip=True, stride=[2], se_ratio=0.25), \n",
#     352     "\n",
#     353     "     BlockArgs(kernel_size=3, num_repeat=3, input_filters=40, output_filters=80, expand_ratio=6, id_skip=True, stride=[2], se_ratio=0.25), \n",
#     354     "\n",
#     355     "     BlockArgs(kernel_size=5, num_repeat=3, input_filters=80, output_filters=112, expand_ratio=6, id_skip=True, stride=[1], se_ratio=0.25), \n",
#     356     "\n",
#     357     "     BlockArgs(kernel_size=5, num_repeat=4, input_filters=112, output_filters=192, expand_ratio=6, id_skip=True, stride=[2], se_ratio=0.25), \n",
#     358     "\n",
#     359     "     BlockArgs(kernel_size=3, num_repeat=1, input_filters=192, output_filters=320, expand_ratio=6, id_skip=True, stride=[1], se_ratio=0.25)]\n",
#     360     "    \n",
#     361     "    GlobalParams(batch_norm_momentum=0.99, batch_norm_epsilon=0.001, dropout_rate=0.2, num_classes=1000, width_coefficient=1.0, \n",
#     362     "                    depth_coefficient=1.0, depth_divisor=8, min_depth=None, drop_connect_rate=0.2, image_size=224)\n",
#     363     "    '''\n",
#     364     "    def __init__(self, block_args, global_params):\n",
#     365     "        super().__init__()\n",
#     366     "        self._block_args = block_args\n",
#     367     "        # 获得标准化的参数\n",
#     368     "        self._bn_mom = 1 - global_params.batch_norm_momentum\n",
#     369     "        self._bn_eps = global_params.batch_norm_epsilon\n",
#     370     "\n",
#     371     "        # 注意力机制的缩放比例\n",
#     372     "        self.has_se = (self._block_args.se_ratio is not None) and (\n",
#     373     "            0 < self._block_args.se_ratio <= 1)\n",
#     374     "        # 是否需要短接边\n",
#     375     "        self.id_skip = block_args.id_skip \n",
#     376     "\n",
#     377     "        Conv2d = get_same_padding_conv2d(image_size=global_params.image_size)\n",
#     378     "\n",
#     379     "        # 1x1卷积通道扩张\n",
#     380     "        inp = self._block_args.input_filters  # number of input channels\n",
#     381     "        oup = self._block_args.input_filters * self._block_args.expand_ratio  # number of output channels\n",
#     382     "        if self._block_args.expand_ratio != 1:\n",
#     383     "            self._expand_conv = Conv2d(\n",
#     384     "                in_channels=inp, out_channels=oup, kernel_size=1, bias=False)\n",
#     385     "            self._bn0 = nn.BatchNorm2d(\n",
#     386     "                num_features=oup, momentum=self._bn_mom, eps=self._bn_eps)\n",
#     387     "\n",
#     388     "        # 深度可分离卷积\n",
#     389     "        k = self._block_args.kernel_size\n",
#     390     "        s = self._block_args.stride\n",
#     391     "        self._depthwise_conv = Conv2d(\n",
#     392     "            in_channels=oup, out_channels=oup, groups=oup,\n",
#     393     "            kernel_size=k, stride=s, bias=False)\n",
#     394     "        self._bn1 = nn.BatchNorm2d(\n",
#     395     "            num_features=oup, momentum=self._bn_mom, eps=self._bn_eps)\n",
#     396     "\n",
#     397     "        # 注意力机制模块组，先进行通道数的收缩再进行通道数的扩张\n",
#     398     "        if self.has_se:\n",
#     399     "            num_squeezed_channels = max(\n",
#     400     "                1, int(self._block_args.input_filters * self._block_args.se_ratio))\n",
#     401     "            self._se_reduce = Conv2d(\n",
#     402     "                in_channels=oup, out_channels=num_squeezed_channels, kernel_size=1)\n",
#     403     "            self._se_expand = Conv2d(\n",
#     404     "                in_channels=num_squeezed_channels, out_channels=oup, kernel_size=1)\n",
#     405     "\n",
#     406     "        # 输出部分\n",
#     407     "        final_oup = self._block_args.output_filters\n",
#     408     "        self._project_conv = Conv2d(\n",
#     409     "            in_channels=oup, out_channels=final_oup, kernel_size=1, bias=False)\n",
#     410     "        self._bn2 = nn.BatchNorm2d(\n",
#     411     "            num_features=final_oup, momentum=self._bn_mom, eps=self._bn_eps)\n",
#     412     "        self._swish = MemoryEfficientSwish()\n",
#     413     "\n",
#     414     "    def forward(self, inputs, drop_connect_rate=None):\n",
#     415     "        x = inputs\n",
#     416     "        if self._block_args.expand_ratio != 1:\n",
#     417     "            x = self._swish(self._bn0(self._expand_conv(inputs)))\n",
#     418     "\n",
#     419     "        x = self._swish(self._bn1(self._depthwise_conv(x)))\n",
#     420     "\n",
#     421     "        # 添加了注意力机制\n",
#     422     "        if self.has_se:\n",
#     423     "            x_squeezed = F.adaptive_avg_pool2d(x, 1)\n",
#     424     "            x_squeezed = self._se_expand(\n",
#     425     "                self._swish(self._se_reduce(x_squeezed)))\n",
#     426     "            x = torch.sigmoid(x_squeezed) * x\n",
#     427     "\n",
#     428     "        x = self._bn2(self._project_conv(x))\n",
#     429     "\n",
#     430     "        # 满足以下条件才可以短接\n",
#     431     "        input_filters, output_filters = self._block_args.input_filters, self._block_args.output_filters\n",
#     432     "        if self.id_skip and self._block_args.stride == 1 and input_filters == output_filters:\n",
#     433     "            if drop_connect_rate:\n",
#     434     "                x = drop_connect(x, p=drop_connect_rate,\n",
#     435     "                                 training=self.training)\n",
#     436     "            x = x + inputs  # skip connection\n",
#     437     "        return x\n",
#     438     "\n",
#     439     "    def set_swish(self, memory_efficient=True):\n",
#     440     "        \"\"\"Sets swish function as memory efficient (for training) or standard (for export)\"\"\"\n",
#     441     "        self._swish = MemoryEfficientSwish() if memory_efficient else Swish()\n",
#     442     "\n",
#     443     "class EfficientNet(nn.Module):\n",
#     444     "    '''\n",
#     445     "    EfficientNet-b0:\n",
#     446     "    [BlockArgs(kernel_size=3, num_repeat=1, input_filters=32, output_filters=16, expand_ratio=1, id_skip=True, stride=[1], se_ratio=0.25), \n",
#     447     "\n",
#     448     "     BlockArgs(kernel_size=3, num_repeat=2, input_filters=16, output_filters=24, expand_ratio=6, id_skip=True, stride=[2], se_ratio=0.25), \n",
#     449     "\n",
#     450     "     BlockArgs(kernel_size=5, num_repeat=2, input_filters=24, output_filters=40, expand_ratio=6, id_skip=True, stride=[2], se_ratio=0.25), \n",
#     451     "\n",
#     452     "     BlockArgs(kernel_size=3, num_repeat=3, input_filters=40, output_filters=80, expand_ratio=6, id_skip=True, stride=[2], se_ratio=0.25), \n",
#     453     "\n",
#     454     "     BlockArgs(kernel_size=5, num_repeat=3, input_filters=80, output_filters=112, expand_ratio=6, id_skip=True, stride=[1], se_ratio=0.25), \n",
#     455     "\n",
#     456     "     BlockArgs(kernel_size=5, num_repeat=4, input_filters=112, output_filters=192, expand_ratio=6, id_skip=True, stride=[2], se_ratio=0.25), \n",
#     457     "\n",
#     458     "     BlockArgs(kernel_size=3, num_repeat=1, input_filters=192, output_filters=320, expand_ratio=6, id_skip=True, stride=[1], se_ratio=0.25)]\n",
#     459     "    \n",
#     460     "    GlobalParams(batch_norm_momentum=0.99, batch_norm_epsilon=0.001, dropout_rate=0.2, num_classes=1000, width_coefficient=1.0, \n",
#     461     "                    depth_coefficient=1.0, depth_divisor=8, min_depth=None, drop_connect_rate=0.2, image_size=224)\n",
#     462     "    '''\n",
#     463     "    def __init__(self, blocks_args=None, global_params=None):\n",
#     464     "        super().__init__()\n",
#     465     "        assert isinstance(blocks_args, list), 'blocks_args should be a list'\n",
#     466     "        assert len(blocks_args) > 0, 'block args must be greater than 0'\n",
#     467     "        self._global_params = global_params\n",
#     468     "        self._blocks_args = blocks_args\n",
#     469     "        # 获得一种卷积方法\n",
#     470     "        Conv2d = get_same_padding_conv2d(image_size=global_params.image_size)\n",
#     471     "\n",
#     472     "        # 获得标准化的参数\n",
#     473     "        bn_mom = 1 - self._global_params.batch_norm_momentum\n",
#     474     "        bn_eps = self._global_params.batch_norm_epsilon\n",
#     475     "\n",
#     476     "        # 网络主干部分开始\n",
#     477     "        # 设定输入进来的是RGB三通道图像\n",
#     478     "        in_channels = 3  \n",
#     479     "        # 利用round_filters可以使得通道数在扩张的时候可以被8整除\n",
#     480     "        out_channels = round_filters(32, self._global_params)\n",
#     481     "\n",
#     482     "        # 卷积+标准化\n",
#     483     "        self._conv_stem = Conv2d(\n",
#     484     "            in_channels, out_channels, kernel_size=3, stride=2, bias=False)\n",
#     485     "        self._bn0 = nn.BatchNorm2d(\n",
#     486     "            num_features=out_channels, momentum=bn_mom, eps=bn_eps)\n",
#     487     "\n",
#     488     "        # 对每个block的参数进行修改\n",
#     489     "        self._blocks = nn.ModuleList([])\n",
#     490     "        for i in range(len(self._blocks_args)):\n",
#     491     "            # 对每个block的参数进行修改，根据所选的efficient版本进行修改\n",
#     492     "            self._blocks_args[i] = self._blocks_args[i]._replace(\n",
#     493     "                input_filters=round_filters(\n",
#     494     "                    self._blocks_args[i].input_filters, self._global_params),\n",
# ...
#     356     "\n",
#     357     "     BlockArgs(kernel_size=5, num_repeat=4, input_filters=112, output_filters=192, expand_ratio=6, id_skip=True, stride=[2], se_ratio=0.25), \n",
#     358     "\n",
#     359     "     BlockArgs(kernel_size=3, num_repeat=1, input_filters=192, output_filters=320, expand_ratio=6, id_skip=True, stride=[1], se_ratio=0.25)]\n",
#     360     "    \n",
#     361     "    GlobalParams(batch_norm_momentum=0.99, batch_norm_epsilon=0.001, dropout_rate=0.2, num_classes=1000, width_coefficient=1.0, \n",
#     362     "                    depth_coefficient=1.0, depth_divisor=8, min_depth=None, drop_connect_rate=0.2, image_size=224)\n",
#     363     "    '''\n",
#     364     "    def __init__(self, block_args, global_params):\n",
#     365     "        super().__init__()\n",
#     366     "        self._block_args = block_args\n",
#     367     "        # 获得标准化的参数\n",
#     368     "        self._bn_mom = 1 - global_params.batch_norm_momentum\n",
#     369     "        self._bn_eps = global_params.batch_norm_epsilon\n",
#     370     "\n",
#     371     "        # 注意力机制的缩放比例\n",
#     372     "        self.has_se = (self._block_args.se_ratio is not None) and (\n",
#     373     "            0 < self._block_args.se_ratio <= 1)\n",
#     374     "        # 是否需要短接边\n",
#     375     "        self.id_skip = block_args.id_skip \n",
#     376     "\n",
#     377     "        Conv2d = get_same_padding_conv2d(image_size=global_params.image_size)\n",
#     378     "\n",
#     379     "        # 1x1卷积通道扩张\n",
#     380     "        inp = self._block_args.input_filters  # number of input channels\n",
#     381     "        oup = self._block_args.input_filters * self._block_args.expand_ratio  # number of output channels\n",
#     382     "        if self._block_args.expand_ratio != 1:\n",
#     383     "            self._expand_conv = Conv2d(\n",
#     384     "                in_channels=inp, out_channels=oup, kernel_size=1, bias=False)\n",
#     385     "            self._bn0 = nn.BatchNorm2d(\n",
#     386     "                num_features=oup, momentum=self._bn_mom, eps=self._bn_eps)\n",
#     387     "\n",
#     388     "        # 深度可分离卷积\n",
#     389     "        k = self._block_args.kernel_size\n",
#     390     "        s = self._block_args.stride\n",
#     391     "        self._depthwise_conv = Conv2d(\n",
#     392     "            in_channels=oup, out_channels=oup, groups=oup,\n",
#     393     "            kernel_size=k, stride=s, bias=False)\n",
#     394     "        self._bn1 = nn.BatchNorm2d(\n",
#     395     "            num_features=oup, momentum=self._bn_mom, eps=self._bn_eps)\n",
#     396     "\n",
#     397     "        # 注意力机制模块组，先进行通道数的收缩再进行通道数的扩张\n",
#     398     "        if self.has_se:\n",
#     399     "            num_squeezed_channels = max(\n",
#     400     "                1, int(self._block_args.input_filters * self._block_args.se_ratio))\n",
#     401     "            self._se_reduce = Conv2d(\n",
#     402     "                in_channels=oup, out_channels=num_squeezed_channels, kernel_size=1)\n",
#     403     "            self._se_expand = Conv2d(\n",
#     404     "                in_channels=num_squeezed_channels, out_channels=oup, kernel_size=1)\n",
#     405     "\n",
#     406     "        # 输出部分\n",
#     407     "        final_oup = self._block_args.output_filters\n",
#     408     "        self._project_conv = Conv2d(\n",
#     409     "            in_channels=oup, out_channels=final_oup, kernel_size=1, bias=False)\n",
#     410     "        self._bn2 = nn.BatchNorm2d(\n",
#     411     "            num_features=final_oup, momentum=self._bn_mom, eps=self._bn_eps)\n",
#     412     "        self._swish = MemoryEfficientSwish()\n",
#     413     "\n",
#     414     "    def forward(self, inputs, drop_connect_rate=None):\n",
#     415     "        x = inputs\n",
#     416     "        if self._block_args.expand_ratio != 1:\n",
#     417     "            x = self._swish(self._bn0(self._expand_conv(inputs)))\n",
#     418     "\n",
#     419     "        x = self._swish(self._bn1(self._depthwise_conv(x)))\n",
#     420     "\n",
#     421     "        # 添加了注意力机制\n",
#     422     "        if self.has_se:\n",
#     423     "            x_squeezed = F.adaptive_avg_pool2d(x, 1)\n",
#     424     "            x_squeezed = self._se_expand(\n",
#     425     "                self._swish(self._se_reduce(x_squeezed)))\n",
#     426     "            x = torch.sigmoid(x_squeezed) * x\n",
#     427     "\n",
#     428     "        x = self._bn2(self._project_conv(x))\n",
#     429     "\n",
#     430     "        # 满足以下条件才可以短接\n",
#     431     "        input_filters, output_filters = self._block_args.input_filters, self._block_args.output_filters\n",
#     432     "        if self.id_skip and self._block_args.stride == 1 and input_filters == output_filters:\n",
#     433     "            if drop_connect_rate:\n",
#     434     "                x = drop_connect(x, p=drop_connect_rate,\n",
#     435     "                                 training=self.training)\n",
#     436     "            x = x + inputs  # skip connection\n",
#     437     "        return x\n",
#     438     "\n",
#     439     "    def set_swish(self, memory_efficient=True):\n",
#     440     "        \"\"\"Sets swish function as memory efficient (for training) or standard (for export)\"\"\"\n",
#     441     "        self._swish = MemoryEfficientSwish() if memory_efficient else Swish()\n",
#     442     "\n",
#     443     "class EfficientNet(nn.Module):\n",
#     444     "    '''\n",
#     445     "    EfficientNet-b0:\n",
#     446     "    [BlockArgs(kernel_size=3, num_repeat=1, input_filters=32, output_filters=16, expand_ratio=1, id_skip=True, stride=[1], se_ratio=0.25), \n",
#     447     "\n",
#     448     "     BlockArgs(kernel_size=3, num_repeat=2, input_filters=16, output_filters=24, expand_ratio=6, id_skip=True, stride=[2], se_ratio=0.25), \n",
#     449     "\n",
#     450     "     BlockArgs(kernel_size=5, num_repeat=2, input_filters=24, output_filters=40, expand_ratio=6, id_skip=True, stride=[2], se_ratio=0.25), \n",
#     451     "\n",
#     452     "     BlockArgs(kernel_size=3, num_repeat=3, input_filters=40, output_filters=80, expand_ratio=6, id_skip=True, stride=[2], se_ratio=0.25), \n",
#     453     "\n",
#     454     "     BlockArgs(kernel_size=5, num_repeat=3, input_filters=80, output_filters=112, expand_ratio=6, id_skip=True, stride=[1], se_ratio=0.25), \n",
#     455     "\n",
#     456     "     BlockArgs(kernel_size=5, num_repeat=4, input_filters=112, output_filters=192, expand_ratio=6, id_skip=True, stride=[2], se_ratio=0.25), \n",
#     457     "\n",
#     458     "     BlockArgs(kernel_size=3, num_repeat=1, input_filters=192, output_filters=320, expand_ratio=6, id_skip=True, stride=[1], se_ratio=0.25)]\n",
#     459     "    \n",
#     460     "    GlobalParams(batch_norm_momentum=0.99, batch_norm_epsilon=0.001, dropout_rate=0.2, num_classes=1000, width_coefficient=1.0, \n",
#     461     "                    depth_coefficient=1.0, depth_divisor=8, min_depth=None, drop_connect_rate=0.2, image_size=224)\n",
#     462     "    '''\n",
#     463     "    def __init__(self, blocks_args=None, global_params=None):\n",
#     464     "        super().__init__()\n",
#     465     "        assert isinstance(blocks_args, list), 'blocks_args should be a list'\n",
#     466     "        assert len(blocks_args) > 0, 'block args must be greater than 0'\n",
#     467     "        self._global_params = global_params\n",
#     468     "        self._blocks_args = blocks_args\n",
#     469     "        # 获得一种卷积方法\n",
#     470     "        Conv2d = get_same_padding_conv2d(image_size=global_params.image_size)\n",
#     471     "\n",
#     472     "        # 获得标准化的参数\n",
#     473     "        bn_mom = 1 - self._global_params.batch_norm_momentum\n",
#     474     "        bn_eps = self._global_params.batch_norm_epsilon\n",
#     475     "\n",
#     476     "        # 网络主干部分开始\n",
#     477     "        # 设定输入进来的是RGB三通道图像\n",
#     478     "        in_channels = 3  \n",
#     479     "        # 利用round_filters可以使得通道数在扩张的时候可以被8整除\n",
#     480     "        out_channels = round_filters(32, self._global_params)\n",
#     481     "\n",
#     482     "        # 卷积+标准化\n",
#     483     "        self._conv_stem = Conv2d(\n",
#     484     "            in_channels, out_channels, kernel_size=3, stride=2, bias=False)\n",
#     485     "        self._bn0 = nn.BatchNorm2d(\n",
#     486     "            num_features=out_channels, momentum=bn_mom, eps=bn_eps)\n",
#     487     "\n",
#     488     "        # 对每个block的参数进行修改\n",
#     489     "        self._blocks = nn.ModuleList([])\n",
#     490     "        for i in range(len(self._blocks_args)):\n",
#     491     "            # 对每个block的参数进行修改，根据所选的efficient版本进行修改\n",
#     492     "            self._blocks_args[i] = self._blocks_args[i]._replace(\n",
#     493     "                input_filters=round_filters(\n",
#     494     "                    self._blocks_args[i].input_filters, self._global_params),\n",
#     495     "                output_filters=round_filters(\n",
#     496     "                    self._blocks_args[i].output_filters, self._global_params),\n",
#     497     "                num_repeat=round_repeats(\n",
#     498     "                    self._blocks_args[i].num_repeat, self._global_params)\n",
#     499     "            )\n",
#     500     "\n",
#     501     "            # 第一次大的Block里面的卷积需要考虑步长和输入进来的通道数！\n",
#     502     "            self._blocks.append(MBConvBlock(self._blocks_args[i], self._global_params))\n",
#     503     "\n",
#     504     "            if self._blocks_args[i].num_repeat > 1:\n",
#     505     "                self._blocks_args[i] = self._blocks_args[i]._replace(input_filters=self._blocks_args[i].output_filters, stride=1)\n",
#     506     "            for _ in range(self._blocks_args[i].num_repeat - 1):\n",
#     507     "                self._blocks.append(MBConvBlock(self._blocks_args[i], self._global_params))\n",
#     508     "\n",
#     509     "        # 增加了head部分\n",
#     510     "        in_channels = self._blocks_args[len(self._blocks_args)-1].output_filters\n",
#     511     "        out_channels = round_filters(1280, self._global_params)\n",
#     512     "\n",
#     513     "        # 卷积+标准化\n",
#     514     "        self._conv_head = Conv2d(in_channels, out_channels, kernel_size=1, bias=False)\n",
#     515     "        self._bn1 = nn.BatchNorm2d(num_features=out_channels, momentum=bn_mom, eps=bn_eps)\n",
#     516     "\n",
#     517     "        # 最后的线性全连接层\n",
#     518     "        self._avg_pooling = nn.AdaptiveAvgPool2d(1)\n",
#     519     "        self._dropout = nn.Dropout(self._global_params.dropout_rate)\n",
#     520     "        self._fc = nn.Linear(out_channels, self._global_params.num_classes)\n",
#     521     "        # 进行swish激活函数\n",
#     522     "        self._swish = MemoryEfficientSwish()\n",
#     523     "\n",
#     524     "    def set_swish(self, memory_efficient=True):\n",
#     525     "        \"\"\"Sets swish function as memory efficient (for training) or standard (for export)\"\"\"\n",
#     526     "        # swish函数\n",
#     527     "        self._swish = MemoryEfficientSwish() if memory_efficient else Swish()\n",
#     528     "        for block in self._blocks:\n",
#     529     "            block.set_swish(memory_efficient)\n",
#     530     "\n",
#     531     "    def extract_features(self, inputs):\n",
#     532     "        \"\"\" Returns output of the final convolution layer \"\"\"\n",
#     533     "\n",
#     534     "        # Stem\n",
#     535     "        x = self._swish(self._bn0(self._conv_stem(inputs)))\n",
#     536     "\n",
#     537     "        # Blocks\n",
#     538     "        for idx, block in enumerate(self._blocks):\n",
#     539     "            drop_connect_rate = self._global_params.drop_connect_rate\n",
#     540     "            if drop_connect_rate:\n",
#     541     "                drop_connect_rate *= float(idx) / len(self._blocks)\n",
#     542     "            x = block(x, drop_connect_rate=drop_connect_rate)\n",
#     543     "        # Head\n",
#     544     "        x = self._swish(self._bn1(self._conv_head(x)))\n",
#     545     "\n",
#     546     "        return x\n",
#     547     "\n",
#     548     "    def forward(self, inputs):\n",
#     549     "        \"\"\" Calls extract_features to extract features, applies final linear layer, and returns logits. \"\"\"\n",
#     550     "        bs = inputs.size(0)\n",
#     551     "        # Convolution layers\n",
#     552     "        x = self.extract_features(inputs)\n",
#     553     "\n",
#     554     "        # Pooling and final linear layer\n",
#     555     "        x = self._avg_pooling(x)\n",
#     556     "        x = x.view(bs, -1)\n",
#     557     "        x = self._dropout(x)\n",
#     558     "        x = self._fc(x)\n",
#     559     "        return x\n",
#     560     "\n",
#     561     "    @classmethod\n",
#     562     "    def from_name(cls, model_name, override_params=None):\n",
#     563     "        cls._check_model_name_is_valid(model_name)\n",
#     564     "        blocks_args, global_params = get_model_params(model_name, override_params)\n",
#     565     "        return cls(blocks_args, global_params)\n",
#     566     "\n",
#     567     "    @classmethod\n",
#     568     "    def from_pretrained(cls, model_name, load_weights=True, advprop=False, num_classes=1000, in_channels=3):\n",
#     569     "        model = cls.from_name(model_name, override_params={'num_classes': num_classes})\n",
#     570     "        if load_weights:\n",
#     571     "            load_pretrained_weights(model, model_name, load_fc=(num_classes == 1000), advprop=advprop)\n",
#     572     "        if in_channels != 3:\n",
#     573     "            Conv2d = get_same_padding_conv2d(image_size = model._global_params.image_size)\n",
#     574     "            out_channels = round_filters(32, model._global_params)\n",
#     575     "            model._conv_stem = Conv2d(in_channels, out_channels, kernel_size=3, stride=2, bias=False)\n",
#     576     "        return model\n",
#     577     "\n",
#     578     "    @classmethod\n",
#     579     "    def get_image_size(cls, model_name):\n",
#     580     "        cls._check_model_name_is_valid(model_name)\n",
#     581     "        _, _, res, _ = efficientnet_params(model_name)\n",
#     582     "        return res\n",
#     583     "\n",
#     584     "    @classmethod\n",
#     585     "    def _check_model_name_is_valid(cls, model_name):\n",
#     586     "        \"\"\" Validates model name. \"\"\"\n",
#     587     "        valid_models = ['efficientnet-b'+str(i) for i in range(9)]\n",
#     588     "        if model_name not in valid_models:\n",
#     589     "            raise ValueError('model_name should be one of: ' + ', '.join(valid_models))\n",
#     590     "\n",
#     591     "\n",
#     592     "\n",
#     593     "if __name__ == '__main__':\n",
#     594     "\n",
#     595     "    inputs = torch.randn(5, 3, 512, 512)\n",
#     596     "\n",
#     597     "    # Test EfficientNet\n",
#     598     "    model = EfficientNet.from_pretrained('efficientnet-b1')\n",
#     599     "    inputs = torch.randn(4, 3, 512, 512)\n",
#     600     "    P = model(inputs)\n",
#     601     "    for idx, p in enumerate(P):\n",
#     602     "        print('P{}: {}'.format(idx, p.size()))\n",
#     603     "    print('# generator parameters:', sum(param.numel() for param in model.parameters()))\n"
#     604    ]
#     605   }
#     606  ],
#     607  "metadata": {
#     608   "kernelspec": {
#     609    "display_name": "torch[python3.9]",
#     610    "language": "python",
#     611    "name": "pytorchuse"
#     612   },
#     613   "language_info": {
#     614    "codemirror_mode": {
#     615     "name": "ipython",
#     616     "version": 3
#     617    },
#     618    "file_extension": ".py",
#     619    "mimetype": "text/x-python",
#     620    "name": "python",
#     621    "nbconvert_exporter": "python",
#     622    "pygments_lexer": "ipython3",
#     623    "version": "3.9.19"
#     624   }
#     625  },
#     626  "nbformat": 4,
#     627  "nbformat_minor": 5
#     628 }
#
# NameError: name 'BlockArgs' is not defined
