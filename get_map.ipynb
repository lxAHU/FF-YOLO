# %%
import os
import xml.etree.ElementTree as ET

from PIL import Image
from tqdm import tqdm
import nbimporter

from utils.utils import get_classes
from utils.utils_map import get_coco_map, get_map
from yolo import YOLO

if __name__ == "__main__":
    '''
    Recall和Precision不像AP是一个面积的概念，因此在门限值（Confidence）不同时，网络的Recall和Precision值是不同的。
    默认情况下，本代码计算的Recall和Precision代表的是当门限值（Confidence）为0.5时，所对应的Recall和Precision值。

    受到mAP计算原理的限制，网络在计算mAP时需要获得近乎所有的预测框，这样才可以计算不同门限条件下的Recall和Precision值
    因此，本代码获得的map_out/detection-results/里面的txt的框的数量一般会比直接predict多一些，目的是列出所有可能的预测框，
    '''
    #------------------------------------------------------------------------------------------------------------------#
    #   map_mode用于指定该文件运行时计算的内容
    #   map_mode为0代表整个map计算流程，包括获得预测结果、获得真实框、计算VOC_map。
    #   map_mode为1代表仅仅获得预测结果。
    #   map_mode为2代表仅仅获得真实框。
    #   map_mode为3代表仅仅计算VOC_map。
    #   map_mode为4代表利用COCO工具箱计算当前数据集的0.50:0.95map。需要获得预测结果、获得真实框后并安装pycocotools才行
    #-------------------------------------------------------------------------------------------------------------------#
    map_mode        = 0
    #--------------------------------------------------------------------------------------#
    #   此处的classes_path用于指定需要测量VOC_map的类别
    #   一般情况下与训练和预测所用的classes_path一致即可
    #--------------------------------------------------------------------------------------#
    classes_path    = 'model_data/voc_classes.txt'
    #--------------------------------------------------------------------------------------#
    #   MINOVERLAP用于指定想要获得的mAP0.x，mAP0.x的意义是什么请同学们百度一下。
    #   比如计算mAP0.75，可以设定MINOVERLAP = 0.75。
    #
    #   当某一预测框与真实框重合度大于MINOVERLAP时，该预测框被认为是正样本，否则为负样本。
    #   因此MINOVERLAP的值越大，预测框要预测的越准确才能被认为是正样本，此时算出来的mAP值越低，
    #--------------------------------------------------------------------------------------#
    MINOVERLAP      = 0.5
    #--------------------------------------------------------------------------------------#
    #   受到mAP计算原理的限制，网络在计算mAP时需要获得近乎所有的预测框，这样才可以计算mAP
    #   因此，confidence的值应当设置的尽量小进而获得全部可能的预测框。
    #   
    #   该值一般不调整。因为计算mAP需要获得近乎所有的预测框，此处的confidence不能随便更改。
    #   想要获得不同门限值下的Recall和Precision值，请修改下方的score_threhold。
    #--------------------------------------------------------------------------------------#
    confidence      = 0.001
    #--------------------------------------------------------------------------------------#
    #   预测时使用到的非极大抑制值的大小，越大表示非极大抑制越不严格。
    #   
    #   该值一般不调整。
    #--------------------------------------------------------------------------------------#
    nms_iou         = 0.5
    #---------------------------------------------------------------------------------------------------------------#
    #   Recall和Precision不像AP是一个面积的概念，因此在门限值不同时，网络的Recall和Precision值是不同的。
    #   
    #   默认情况下，本代码计算的Recall和Precision代表的是当门限值为0.5（此处定义为score_threhold）时所对应的Recall和Precision值。
    #   因为计算mAP需要获得近乎所有的预测框，上面定义的confidence不能随便更改。
    #   这里专门定义一个score_threhold用于代表门限值，进而在计算mAP时找到门限值对应的Recall和Precision值。
    #---------------------------------------------------------------------------------------------------------------#
    score_threhold  = 0.5
    #-------------------------------------------------------#
    #   map_vis用于指定是否开启VOC_map计算的可视化
    #-------------------------------------------------------#
    map_vis         = False
    #-------------------------------------------------------#
    #   指向VOC数据集所在的文件夹
    #   默认指向根目录下的VOC数据集
    #-------------------------------------------------------#
    VOCdevkit_path  = 'VOCdevkit'
    #-------------------------------------------------------#
    #   结果输出的文件夹，默认为map_out
    #-------------------------------------------------------#
    map_out_path    = 'map_out'

    image_ids = open(os.path.join(VOCdevkit_path, "VOC2007/ImageSets/Main/test.txt")).read().strip().split()

    if not os.path.exists(map_out_path):
        os.makedirs(map_out_path)
    if not os.path.exists(os.path.join(map_out_path, 'ground-truth')):
        os.makedirs(os.path.join(map_out_path, 'ground-truth'))
    if not os.path.exists(os.path.join(map_out_path, 'detection-results')):
        os.makedirs(os.path.join(map_out_path, 'detection-results'))
    if not os.path.exists(os.path.join(map_out_path, 'images-optional')):
        os.makedirs(os.path.join(map_out_path, 'images-optional'))

    class_names, _ = get_classes(classes_path)

    if map_mode == 0 or map_mode == 1:
        print("Load model.")
        yolo = YOLO(confidence = confidence, nms_iou = nms_iou)
        print("Load model done.")

        print("Get predict result.")
        for image_id in tqdm(image_ids):
            image_path  = os.path.join(VOCdevkit_path, "VOC2007/JPEGImages/"+image_id+".jpg")
            image       = Image.open(image_path)
            if map_vis:
                image.save(os.path.join(map_out_path, "images-optional/" + image_id + ".jpg"))
            yolo.get_map_txt(image_id, image, class_names, map_out_path)
        print("Get predict result done.")
        
    if map_mode == 0 or map_mode == 2:
        print("Get ground truth result.")
        for image_id in tqdm(image_ids):
            with open(os.path.join(map_out_path, "ground-truth/"+image_id+".txt"), "w") as new_f:
                root = ET.parse(os.path.join(VOCdevkit_path, "VOC2007/Annotations/"+image_id+".xml")).getroot()
                for obj in root.findall('object'):
                    difficult_flag = False
                    if obj.find('difficult')!=None:
                        difficult = obj.find('difficult').text
                        if int(difficult)==1:
                            difficult_flag = True
                    obj_name = obj.find('name').text
                    if obj_name not in class_names:
                        continue
                    bndbox  = obj.find('bndbox')
                    left    = bndbox.find('xmin').text
                    top     = bndbox.find('ymin').text
                    right   = bndbox.find('xmax').text
                    bottom  = bndbox.find('ymax').text

                    if difficult_flag:
                        new_f.write("%s %s %s %s %s difficult\n" % (obj_name, left, top, right, bottom))
                    else:
                        new_f.write("%s %s %s %s %s\n" % (obj_name, left, top, right, bottom))
        print("Get ground truth result done.")

    if map_mode == 0 or map_mode == 3:
        print("Get map.")
        get_map(MINOVERLAP, True, score_threhold = score_threhold, path = map_out_path)
        print("Get map done.")

    if map_mode == 4:
        print("Get map.")
        get_coco_map(class_names = class_names, path = map_out_path)
        print("Get map done.")
# Out:
# Load model.
# initialize network with normal type
#   0%|                                                                                         | 0/2151 [00:00<?, ?it/s]
# Fusing layers...
# logs/best_epoch_weights.pth model, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path |              logs/best_epoch_weights.pth|
# |             classes_path |               model_data/voc_classes.txt|
# |              input_shape |                               [640, 640]|
# |                      phi |                                        s|
# |               confidence |                                    0.001|
# |                  nms_iou |                                      0.5|
# |          letterbox_image |                                     True|
# |                     cuda |                                    False|
# ----------------------------------------------------------------------
# Load model done.
# Get predict result.
#   3%|██▎                                                                             | 62/2151 [00:15<08:55,  3.90it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 102
#     100         if map_vis:
#     101             image.save(os.path.join(map_out_path, "images-optional/" + image_id + ".jpg"))
# --> 102         yolo.get_map_txt(image_id, image, class_names, map_out_path)
#     103     print("Get predict result done.")
#     105 if map_mode == 0 or map_mode == 2:
#
# File D:\StudyTool\jupyter-projects\Mdoule\yolov8-pytorch-master_1\yolo.ipynb:391, in get_map_txt(self, image_id, image, class_names, map_out_path)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "6c8bb67a",
#       7    "metadata": {},
#       8    "outputs": [
#       9     {
#      10      "ename": "ModuleNotFoundError",
#      11      "evalue": "No module named 'nets.yolo'",
#      12      "output_type": "error",
#      13      "traceback": [
#      14       "\u001b---------------------------------------------------------------------------\u001b",
#      15       "\u001bModuleNotFoundError\u001b                       Traceback (most recent call last)",
#      16       "Cell \u001bIn[1], line 10\u001b\n\u001b      7\u001b \u001bimport\u001b \u001btorch\u001b\u001b.\u001b\u001bnn\u001b \u001bas\u001b \u001bnn\u001b\n\u001b      8\u001b \u001bfrom\u001b \u001bPIL\u001b \u001bimport\u001b ImageDraw, ImageFont\n\u001b---> 10\u001b \u001bfrom\u001b \u001bnets\u001b\u001b.\u001b\u001byolo\u001b \u001bimport\u001b YoloBody\n\u001b     11\u001b \u001bfrom\u001b \u001butils\u001b\u001b.\u001b\u001butils\u001b \u001bimport\u001b (cvtColor, get_classes, preprocess_input,\n\u001b     12\u001b                          resize_image, show_config)\n\u001b     13\u001b \u001bfrom\u001b \u001butils\u001b\u001b.\u001b\u001butils_bbox\u001b \u001bimport\u001b DecodeBox\n",
#      17       "\u001bModuleNotFoundError\u001b: No module named 'nets.yolo'"
#      18      ]
#      19     }
#      20    ],
#      21    "source": [
#      22     "import colorsys\n",
#      23     "import os\n",
#      24     "import time\n",
#      25     "\n",
#      26     "import numpy as np\n",
#      27     "import torch\n",
#      28     "import torch.nn as nn\n",
#      29     "from PIL import ImageDraw, ImageFont\n",
#      30     "\n",
#      31     "from nets.yolo import YoloBody\n",
#      32     "from utils.utils import (cvtColor, get_classes, preprocess_input,\n",
#      33     "                         resize_image, show_config)\n",
#      34     "from utils.utils_bbox import DecodeBox\n",
#      35     "\n",
#      36     "'''\n",
#      37     "训练自己的数据集必看注释！\n",
#      38     "'''\n",
#      39     "class YOLO(object):\n",
#      40     "    _defaults = {\n",
#      41     "        #--------------------------------------------------------------------------#\n",
#      42     "        #   使用自己训练好的模型进行预测一定要修改model_path和classes_path！\n",
#      43     "        #   model_path指向logs文件夹下的权值文件，classes_path指向model_data下的txt\n",
#      44     "        #\n",
#      45     "        #   训练好后logs文件夹下存在多个权值文件，选择验证集损失较低的即可。\n",
#      46     "        #   验证集损失较低不代表mAP较高，仅代表该权值在验证集上泛化性能较好。\n",
#      47     "        #   如果出现shape不匹配，同时要注意训练时的model_path和classes_path参数的修改\n",
#      48     "        #--------------------------------------------------------------------------#\n",
#      49     "        \"model_path\"        : 'logs/best_epoch_weights.pth',\n",
#      50     "        \"classes_path\"      : 'model_data/voc_classes.txt',\n",
#      51     "        #---------------------------------------------------------------------#\n",
#      52     "        #   输入图片的大小，必须为32的倍数。\n",
#      53     "        #---------------------------------------------------------------------#\n",
#      54     "        \"input_shape\"       : [640, 640],\n",
#      55     "        #------------------------------------------------------#\n",
#      56     "        #   所使用到的yolov8的版本：\n",
#      57     "        #   n : 对应yolov8_n\n",
#      58     "        #   s : 对应yolov8_s\n",
#      59     "        #   m : 对应yolov8_m\n",
#      60     "        #   l : 对应yolov8_l\n",
#      61     "        #   x : 对应yolov8_x\n",
#      62     "        #------------------------------------------------------#\n",
#      63     "        \"phi\"               : 's',\n",
#      64     "        #---------------------------------------------------------------------#\n",
#      65     "        #   只有得分大于置信度的预测框会被保留下来\n",
#      66     "        #---------------------------------------------------------------------#\n",
#      67     "        \"confidence\"        : 0.5,\n",
#      68     "        #---------------------------------------------------------------------#\n",
#      69     "        #   非极大抑制所用到的nms_iou大小\n",
#      70     "        #---------------------------------------------------------------------#\n",
#      71     "        \"nms_iou\"           : 0.3,\n",
#      72     "        #---------------------------------------------------------------------#\n",
#      73     "        #   该变量用于控制是否使用letterbox_image对输入图像进行不失真的resize，\n",
#      74     "        #   在多次测试后，发现关闭letterbox_image直接resize的效果更好\n",
#      75     "        #---------------------------------------------------------------------#\n",
#      76     "        \"letterbox_image\"   : True,\n",
#      77     "        #-------------------------------#\n",
#      78     "        #   是否使用Cuda\n",
#      79     "        #   没有GPU可以设置成False\n",
#      80     "        #-------------------------------#\n",
#      81     "        \"cuda\"              : False,\n",
#      82     "    }\n",
#      83     "\n",
#      84     "    @classmethod\n",
#      85     "    def get_defaults(cls, n):\n",
#      86     "        if n in cls._defaults:\n",
#      87     "            return cls._defaults[n]\n",
#      88     "        else:\n",
#      89     "            return \"Unrecognized attribute name '\" + n + \"'\"\n",
#      90     "\n",
#      91     "    #---------------------------------------------------#\n",
#      92     "    #   初始化YOLO\n",
#      93     "    #---------------------------------------------------#\n",
#      94     "    def __init__(self, **kwargs):\n",
#      95     "        self.__dict__.update(self._defaults)\n",
#      96     "        for name, value in kwargs.items():\n",
#      97     "            setattr(self, name, value)\n",
#      98     "            self._defaults[name] = value \n",
#      99     "            \n",
#     100     "        #---------------------------------------------------#\n",
#     101     "        #   获得种类和先验框的数量\n",
#     102     "        #---------------------------------------------------#\n",
#     103     "        self.class_names, self.num_classes  = get_classes(self.classes_path)\n",
#     104     "        self.bbox_util                      = DecodeBox(self.num_classes, (self.input_shape[0], self.input_shape[1]))\n",
#     105     "\n",
#     106     "        #---------------------------------------------------#\n",
#     107     "        #   画框设置不同的颜色\n",
#     108     "        #---------------------------------------------------#\n",
#     109     "        hsv_tuples = [(x / self.num_classes, 1., 1.) for x in range(self.num_classes)]\n",
#     110     "        self.colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))\n",
#     111     "        self.colors = list(map(lambda x: (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)), self.colors))\n",
#     112     "        self.generate()\n",
#     113     "\n",
#     114     "        show_config(**self._defaults)\n",
#     115     "\n",
#     116     "    #---------------------------------------------------#\n",
#     117     "    #   生成模型\n",
#     118     "    #---------------------------------------------------#\n",
#     119     "    def generate(self, onnx=False):\n",
#     120     "        #---------------------------------------------------#\n",
#     121     "        #   建立yolo模型，载入yolo模型的权重\n",
#     122     "        #---------------------------------------------------#\n",
#     123     "        self.net    = YoloBody(self.input_shape, self.num_classes, self.phi)\n",
#     124     "        \n",
#     125     "        device      = torch.device('cuda' if torch.cuda.is_available() else 'cpu')\n",
#     126     "        self.net.load_state_dict(torch.load(self.model_path, map_location=device))\n",
#     127     "        self.net    = self.net.fuse().eval()\n",
#     128     "        print('{} model, and classes loaded.'.format(self.model_path))\n",
#     129     "        if not onnx:\n",
#     130     "            if self.cuda:\n",
#     131     "                self.net = nn.DataParallel(self.net)\n",
#     132     "                self.net = self.net.cuda()\n",
#     133     "\n",
#     134     "    #---------------------------------------------------#\n",
#     135     "    #   检测图片\n",
#     136     "    #---------------------------------------------------#\n",
#     137     "    def detect_image(self, image, crop = False, count = False):\n",
#     138     "        #---------------------------------------------------#\n",
#     139     "        #   计算输入图片的高和宽\n",
#     140     "        #---------------------------------------------------#\n",
#     141     "        image_shape = np.array(np.shape(image)[0:2])\n",
#     142     "        #---------------------------------------------------------#\n",
#     143     "        #   在这里将图像转换成RGB图像，防止灰度图在预测时报错。\n",
#     144     "        #   代码仅仅支持RGB图像的预测，所有其它类型的图像都会转化成RGB\n",
#     145     "        #---------------------------------------------------------#\n",
#     146     "        image       = cvtColor(image)\n",
#     147     "        #---------------------------------------------------------#\n",
#     148     "        #   给图像增加灰条，实现不失真的resize\n",
#     149     "        #   也可以直接resize进行识别\n",
#     150     "        #---------------------------------------------------------#\n",
#     151     "        image_data  = resize_image(image, (self.input_shape[1], self.input_shape[0]), self.letterbox_image)\n",
#     152     "        #---------------------------------------------------------#\n",
#     153     "        #   添加上batch_size维度\n",
#     154     "        #   h, w, 3 => 3, h, w => 1, 3, h, w\n",
#     155     "        #---------------------------------------------------------#\n",
#     156     "        image_data  = np.expand_dims(np.transpose(preprocess_input(np.array(image_data, dtype='float32')), (2, 0, 1)), 0)\n",
#     157     "\n",
#     158     "        with torch.no_grad():\n",
#     159     "            images = torch.from_numpy(image_data)\n",
#     160     "            if self.cuda:\n",
#     161     "                images = images.cuda()\n",
#     162     "            #---------------------------------------------------------#\n",
#     163     "            #   将图像输入网络当中进行预测！\n",
#     164     "            #---------------------------------------------------------#\n",
#     165     "            outputs = self.net(images)\n",
#     166     "            outputs = self.bbox_util.decode_box(outputs)\n",
#     167     "            #---------------------------------------------------------#\n",
#     168     "            #   将预测框进行堆叠，然后进行非极大抑制\n",
#     169     "            #---------------------------------------------------------#\n",
#     170     "            results = self.bbox_util.non_max_suppression(outputs, self.num_classes, self.input_shape, \n",
#     171     "                        image_shape, self.letterbox_image, conf_thres = self.confidence, nms_thres = self.nms_iou)\n",
#     172     "                                                    \n",
#     173     "            if results[0] is None: \n",
#     174     "                return image\n",
#     175     "\n",
#     176     "            top_label   = np.array(results[0][:, 5], dtype = 'int32')\n",
#     177     "            top_conf    = results[0][:, 4]\n",
#     178     "            top_boxes   = results[0][:, :4]\n",
#     179     "        #---------------------------------------------------------#\n",
#     180     "        #   设置字体与边框厚度\n",
#     181     "        #---------------------------------------------------------#\n",
#     182     "        font        = ImageFont.truetype(font='model_data/simhei.ttf', size=np.floor(3e-2 * image.size[1] + 0.5).astype('int32'))\n",
#     183     "        thickness   = int(max((image.size[0] + image.size[1]) // np.mean(self.input_shape), 1))\n",
#     184     "        #---------------------------------------------------------#\n",
#     185     "        #   计数\n",
#     186     "        #---------------------------------------------------------#\n",
#     187     "        if count:\n",
#     188     "            print(\"top_label:\", top_label)\n",
#     189     "            classes_nums    = np.zeros([self.num_classes])\n",
#     190     "            for i in range(self.num_classes):\n",
#     191     "                num = np.sum(top_label == i)\n",
#     192     "                if num > 0:\n",
#     193     "                    print(self.class_names[i], \" : \", num)\n",
#     194     "                classes_nums[i] = num\n",
#     195     "            print(\"classes_nums:\", classes_nums)\n",
#     196     "        #---------------------------------------------------------#\n",
#     197     "        #   是否进行目标的裁剪\n",
#     198     "        #---------------------------------------------------------#\n",
#     199     "        if crop:\n",
#     200     "            for i, c in list(enumerate(top_boxes)):\n",
#     201     "                top, left, bottom, right = top_boxes[i]\n",
#     202     "                top     = max(0, np.floor(top).astype('int32'))\n",
#     203     "                left    = max(0, np.floor(left).astype('int32'))\n",
#     204     "                bottom  = min(image.size[1], np.floor(bottom).astype('int32'))\n",
#     205     "                right   = min(image.size[0], np.floor(right).astype('int32'))\n",
#     206     "                \n",
#     207     "                dir_save_path = \"img_crop\"\n",
#     208     "                if not os.path.exists(dir_save_path):\n",
#     209     "                    os.makedirs(dir_save_path)\n",
#     210     "                crop_image = image.crop([left, top, right, bottom])\n",
#     211     "                crop_image.save(os.path.join(dir_save_path, \"crop_\" + str(i) + \".png\"), quality=95, subsampling=0)\n",
#     212     "                print(\"save crop_\" + str(i) + \".png to \" + dir_save_path)\n",
#     213     "        #---------------------------------------------------------#\n",
#     214     "        #   图像绘制\n",
#     215     "        #---------------------------------------------------------#\n",
#     216     "        for i, c in list(enumerate(top_label)):\n",
#     217     "            predicted_class = self.class_names[int(c)]\n",
#     218     "            box             = top_boxes[i]\n",
#     219     "            score           = top_conf[i]\n",
#     220     "\n",
#     221     "            top, left, bottom, right = box\n",
#     222     "\n",
#     223     "            top     = max(0, np.floor(top).astype('int32'))\n",
#     224     "            left    = max(0, np.floor(left).astype('int32'))\n",
#     225     "            bottom  = min(image.size[1], np.floor(bottom).astype('int32'))\n",
#     226     "            right   = min(image.size[0], np.floor(right).astype('int32'))\n",
#     227     "\n",
#     228     "            label = '{} {:.2f}'.format(predicted_class, score)\n",
#     229     "            draw = ImageDraw.Draw(image)\n",
#     230     "            label_size = draw.textsize(label, font)\n",
#     231     "            label = label.encode('utf-8')\n",
#     232     "            print(label, top, left, bottom, right)\n",
#     233     "            \n",
#     234     "            if top - label_size[1] >= 0:\n",
#     235     "                text_origin = np.array([left, top - label_size[1]])\n",
#     236     "            else:\n",
#     237     "                text_origin = np.array([left, top + 1])\n",
#     238     "\n",
#     239     "            for i in range(thickness):\n",
#     240     "                draw.rectangle([left + i, top + i, right - i, bottom - i], outline=self.colors[c])\n",
#     241     "            draw.rectangle([tuple(text_origin), tuple(text_origin + label_size)], fill=self.colors[c])\n",
#     242     "            draw.text(text_origin, str(label,'UTF-8'), fill=(0, 0, 0), font=font)\n",
#     243     "            del draw\n",
#     244     "\n",
#     245     "        return image\n",
#     246     "\n",
#     247     "    def get_FPS(self, image, test_interval):\n",
#     248     "        image_shape = np.array(np.shape(image)[0:2])\n",
#     249     "        #---------------------------------------------------------#\n",
#     250     "        #   在这里将图像转换成RGB图像，防止灰度图在预测时报错。\n",
#     251     "        #   代码仅仅支持RGB图像的预测，所有其它类型的图像都会转化成RGB\n",
#     252     "        #---------------------------------------------------------#\n",
#     253     "        image       = cvtColor(image)\n",
#     254     "        #---------------------------------------------------------#\n",
#     255     "        #   给图像增加灰条，实现不失真的resize\n",
#     256     "        #   也可以直接resize进行识别\n",
#     257     "        #---------------------------------------------------------#\n",
#     258     "        image_data  = resize_image(image, (self.input_shape[1], self.input_shape[0]), self.letterbox_image)\n",
#     259     "        #---------------------------------------------------------#\n",
#     260     "        #   添加上batch_size维度\n",
#     261     "        #---------------------------------------------------------#\n",
#     262     "        image_data  = np.expand_dims(np.transpose(preprocess_input(np.array(image_data, dtype='float32')), (2, 0, 1)), 0)\n",
#     263     "\n",
#     264     "        with torch.no_grad():\n",
#     265     "            images = torch.from_numpy(image_data)\n",
#     266     "            if self.cuda:\n",
#     267     "                images = images.cuda()\n",
#     268     "            #---------------------------------------------------------#\n",
#     269     "            #   将图像输入网络当中进行预测！\n",
#     270     "            #---------------------------------------------------------#\n",
#     271     "            outputs = self.net(images)\n",
#     272     "            outputs = self.bbox_util.decode_box(outputs)\n",
#     273     "            #---------------------------------------------------------#\n",
#     274     "            #   将预测框进行堆叠，然后进行非极大抑制\n",
#     275     "            #---------------------------------------------------------#\n",
#     276     "            results = self.bbox_util.non_max_suppression(outputs, self.num_classes, self.input_shape, \n",
#     277     "                        image_shape, self.letterbox_image, conf_thres = self.confidence, nms_thres = self.nms_iou)\n",
#     278     "                                                    \n",
#     279     "        t1 = time.time()\n",
#     280     "        for _ in range(test_interval):\n",
#     281     "            with torch.no_grad():\n",
#     282     "                #---------------------------------------------------------#\n",
#     283     "                #   将图像输入网络当中进行预测！\n",
#     284     "                #---------------------------------------------------------#\n",
#     285     "                outputs = self.net(images)\n",
#     286     "                outputs = self.bbox_util.decode_box(outputs)\n",
#     287     "                #---------------------------------------------------------#\n",
#     288     "                #   将预测框进行堆叠，然后进行非极大抑制\n",
#     289     "                #---------------------------------------------------------#\n",
#     290     "                results = self.bbox_util.non_max_suppression(outputs, self.num_classes, self.input_shape, \n",
#     291     "                            image_shape, self.letterbox_image, conf_thres = self.confidence, nms_thres = self.nms_iou)\n",
#     292     "                                \n",
#     293     "        t2 = time.time()\n",
#     294     "        tact_time = (t2 - t1) / test_interval\n",
#     295     "        return tact_time\n",
#     296     "\n",
#     297     "    def detect_heatmap(self, image, heatmap_save_path):\n",
#     298     "        import cv2\n",
#     299     "        import matplotlib.pyplot as plt\n",
#     300     "        def sigmoid(x):\n",
#     301     "            y = 1.0 / (1.0 + np.exp(-x))\n",
#     302     "            return y\n",
#     303     "        #---------------------------------------------------------#\n",
#     304     "        #   在这里将图像转换成RGB图像，防止灰度图在预测时报错。\n",
#     305     "        #   代码仅仅支持RGB图像的预测，所有其它类型的图像都会转化成RGB\n",
#     306     "        #---------------------------------------------------------#\n",
#     307     "        image       = cvtColor(image)\n",
#     308     "        #---------------------------------------------------------#\n",
#     309     "        #   给图像增加灰条，实现不失真的resize\n",
#     310     "        #   也可以直接resize进行识别\n",
#     311     "        #---------------------------------------------------------#\n",
#     312     "        image_data  = resize_image(image, (self.input_shape[1],self.input_shape[0]), self.letterbox_image)\n",
#     313     "        #---------------------------------------------------------#\n",
#     314     "        #   添加上batch_size维度\n",
#     315     "        #---------------------------------------------------------#\n",
#     316     "        image_data  = np.expand_dims(np.transpose(preprocess_input(np.array(image_data, dtype='float32')), (2, 0, 1)), 0)\n",
#     317     "\n",
#     318     "        with torch.no_grad():\n",
#     319     "            images = torch.from_numpy(image_data)\n",
#     320     "            if self.cuda:\n",
#     321     "                images = images.cuda()\n",
#     322     "            #---------------------------------------------------------#\n",
#     323     "            #   将图像输入网络当中进行预测！\n",
#     324     "            #---------------------------------------------------------#\n",
#     325     "            dbox, cls, x, anchors, strides = self.net(images)\n",
#     326     "            outputs = [xi.split((xi.size()[1] - self.num_classes, self.num_classes), 1)[1] for xi in x]\n",
#     327     "        \n",
#     328     "        plt.imshow(image, alpha=1)\n",
#     329     "        plt.axis('off')\n",
#     330     "        mask    = np.zeros((image.size[1], image.size[0]))\n",
#     331     "        for sub_output in outputs:\n",
#     332     "            sub_output = sub_output.cpu().numpy()\n",
#     333     "            b, c, h, w = np.shape(sub_output)\n",
#     334     "            sub_output = np.transpose(np.reshape(sub_output, [b, -1, h, w]), [0, 2, 3, 1])[0]\n",
#     335     "            score      = np.max(sigmoid(sub_output[..., :]), -1)\n",
#     336     "            score      = cv2.resize(score, (image.size[0], image.size[1]))\n",
#     337     "            normed_score    = (score * 255).astype('uint8')\n",
#     338     "            mask            = np.maximum(mask, normed_score)\n",
#     339     "            \n",
#     340     "        plt.imshow(mask, alpha=0.5, interpolation='nearest', cmap=\"jet\")\n",
#     341     "\n",
#     342     "        plt.axis('off')\n",
#     343     "        plt.subplots_adjust(top=1, bottom=0, right=1,  left=0, hspace=0, wspace=0)\n",
#     344     "        plt.margins(0, 0)\n",
#     345     "        plt.savefig(heatmap_save_path, dpi=200, bbox_inches='tight', pad_inches = -0.1)\n",
#     346     "        print(\"Save to the \" + heatmap_save_path)\n",
#     347     "        plt.show()\n",
#     348     "\n",
#     349     "    def convert_to_onnx(self, simplify, model_path):\n",
#     350     "        import onnx\n",
#     351     "        self.generate(onnx=True)\n",
#     352     "\n",
#     353     "        im                  = torch.zeros(1, 3, *self.input_shape).to('cpu')  # image size(1, 3, 512, 512) BCHW\n",
#     354     "        input_layer_names   = [\"images\"]\n",
#     355     "        output_layer_names  = [\"output\"]\n",
#     356     "        \n",
#     357     "        # Export the model\n",
#     358     "        print(f'Starting export with onnx {onnx.__version__}.')\n",
#     359     "        torch.onnx.export(self.net,\n",
#     360     "                        im,\n",
#     361     "                        f               = model_path,\n",
#     362     "                        verbose         = False,\n",
#     363     "                        opset_version   = 12,\n",
#     364     "                        training        = torch.onnx.TrainingMode.EVAL,\n",
#     365     "                        do_constant_folding = True,\n",
#     366     "                        input_names     = input_layer_names,\n",
#     367     "                        output_names    = output_layer_names,\n",
#     368     "                        dynamic_axes    = None)\n",
#     369     "\n",
#     370     "        # Checks\n",
#     371     "        model_onnx = onnx.load(model_path)  # load onnx model\n",
#     372     "        onnx.checker.check_model(model_onnx)  # check onnx model\n",
#     373     "\n",
#     374     "        # Simplify onnx\n",
#     375     "        if simplify:\n",
#     376     "            import onnxsim\n",
#     377     "            print(f'Simplifying with onnx-simplifier {onnxsim.__version__}.')\n",
#     378     "            model_onnx, check = onnxsim.simplify(\n",
#     379     "                model_onnx,\n",
#     380     "                dynamic_input_shape=False,\n",
#     381     "                input_shapes=None)\n",
#     382     "            assert check, 'assert check failed'\n",
#     383     "            onnx.save(model_onnx, model_path)\n",
#     384     "\n",
#     385     "        print('Onnx model save as {}'.format(model_path))\n",
#     386     "\n",
#     387     "    def get_map_txt(self, image_id, image, class_names, map_out_path):\n",
#     388     "        f = open(os.path.join(map_out_path, \"detection-results/\"+image_id+\".txt\"), \"w\", encoding='utf-8') \n",
#     389     "        image_shape = np.array(np.shape(image)[0:2])\n",
#     390     "        #---------------------------------------------------------#\n",
# --> 391     "        #   在这里将图像转换成RGB图像，防止灰度图在预测时报错。\n",
#     392     "        #   代码仅仅支持RGB图像的预测，所有其它类型的图像都会转化成RGB\n",
#     393     "        #---------------------------------------------------------#\n",
#     394     "        image       = cvtColor(image)\n",
#     395     "        #---------------------------------------------------------#\n",
#     396     "        #   给图像增加灰条，实现不失真的resize\n",
#     397     "        #   也可以直接resize进行识别\n",
#     398     "        #---------------------------------------------------------#\n",
#     399     "        image_data  = resize_image(image, (self.input_shape[1], self.input_shape[0]), self.letterbox_image)\n",
#     400     "        #---------------------------------------------------------#\n",
#     401     "        #   添加上batch_size维度\n",
#     402     "        #---------------------------------------------------------#\n",
#     403     "        image_data  = np.expand_dims(np.transpose(preprocess_input(np.array(image_data, dtype='float32')), (2, 0, 1)), 0)\n",
#     404     "\n",
#     405     "        with torch.no_grad():\n",
#     406     "            images = torch.from_numpy(image_data)\n",
#     407     "            if self.cuda:\n",
#     408     "                images = images.cuda()\n",
#     409     "            #---------------------------------------------------------#\n",
#     410     "            #   将图像输入网络当中进行预测！\n",
#     411     "            #---------------------------------------------------------#\n",
#     412     "            outputs = self.net(images)\n",
#     413     "            outputs = self.bbox_util.decode_box(outputs)\n",
#     414     "            #---------------------------------------------------------#\n",
#     415     "            #   将预测框进行堆叠，然后进行非极大抑制\n",
#     416     "            #---------------------------------------------------------#\n",
#     417     "            results = self.bbox_util.non_max_suppression(outputs, self.num_classes, self.input_shape, \n",
#     418     "                        image_shape, self.letterbox_image, conf_thres = self.confidence, nms_thres = self.nms_iou)\n",
#     419     "                                                    \n",
#     420     "            if results[0] is None: \n",
#     421     "                return \n",
#     422     "\n",
#     423     "            top_label   = np.array(results[0][:, 5], dtype = 'int32')\n",
#     424     "            top_conf    = results[0][:, 4]\n",
#     425     "            top_boxes   = results[0][:, :4]\n",
#     426     "\n",
#     427     "        for i, c in list(enumerate(top_label)):\n",
#     428     "            predicted_class = self.class_names[int(c)]\n",
#     429     "            box             = top_boxes[i]\n",
#     430     "            score           = str(top_conf[i])\n",
#     431     "\n",
#     432     "            top, left, bottom, right = box\n",
#     433     "            if predicted_class not in class_names:\n",
#     434     "                continue\n",
#     435     "\n",
#     436     "            f.write(\"%s %s %s %s %s %s\\n\" % (predicted_class, score[:6], str(int(left)), str(int(top)), str(int(right)),str(int(bottom))))\n",
#     437     "\n",
#     438     "        f.close()\n",
#     439     "        return \n"
#     440    ]
#     441   },
#     442   {
#     443    "cell_type": "code",
#     444    "execution_count": null,
#     445    "id": "ed1db288",
#     446    "metadata": {},
#     447    "outputs": [],
#     448    "source": []
#     449   }
#     450  ],
#     451  "metadata": {
#     452   "kernelspec": {
#     453    "display_name": "torch[python3.9]",
#     454    "language": "python",
#     455    "name": "pytorchuse"
#     456   },
#     457   "language_info": {
#     458    "codemirror_mode": {
#     459     "name": "ipython",
#     460     "version": 3
#     461    },
#     462    "file_extension": ".py",
#     463    "mimetype": "text/x-python",
#     464    "name": "python",
#     465    "nbconvert_exporter": "python",
#     466    "pygments_lexer": "ipython3",
#     467    "version": "3.9.19"
#     468   }
#     469  },
#     470  "nbformat": 4,
#     471  "nbformat_minor": 5
#     472 }
#
# File D:\StudyTool\Anaconda\envs\pytorchuse\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File D:\StudyTool\Anaconda\envs\pytorchuse\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File D:\StudyTool\jupyter-projects\Mdoule\yolov8-pytorch-master_1\nets\yolo.ipynb:124, in forward(self, x)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": null,
#       6    "id": "6e35836d",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import numpy as np\n",
#      11     "import torch\n",
#      12     "import torch.nn as nn\n",
#      13     "\n",
#      14     "from nets.backbone import Backbone, C2f, Conv\n",
#      15     "from nets.yolo_training import weights_init\n",
#      16     "from utils.utils_bbox import make_anchors\n",
#      17     "\n",
#      18     "def fuse_conv_and_bn(conv, bn):\n",
#      19     "    # 混合Conv2d + BatchNorm2d 减少计算量\n",
#      20     "    # Fuse Conv2d() and BatchNorm2d() layers https://tehnokv.com/posts/fusing-batchnorm-and-conv/\n",
#      21     "    fusedconv = nn.Conv2d(conv.in_channels,\n",
#      22     "                          conv.out_channels,\n",
#      23     "                          kernel_size=conv.kernel_size,\n",
#      24     "                          stride=conv.stride,\n",
#      25     "                          padding=conv.padding,\n",
#      26     "                          dilation=conv.dilation,\n",
#      27     "                          groups=conv.groups,\n",
#      28     "                          bias=True).requires_grad_(False).to(conv.weight.device)\n",
#      29     "\n",
#      30     "    # 准备kernel\n",
#      31     "    w_conv = conv.weight.clone().view(conv.out_channels, -1)\n",
#      32     "    w_bn = torch.diag(bn.weight.div(torch.sqrt(bn.eps + bn.running_var)))\n",
#      33     "    fusedconv.weight.copy_(torch.mm(w_bn, w_conv).view(fusedconv.weight.shape))\n",
#      34     "\n",
#      35     "    # 准备bias\n",
#      36     "    b_conv = torch.zeros(conv.weight.size(0), device=conv.weight.device) if conv.bias is None else conv.bias\n",
#      37     "    b_bn = bn.bias - bn.weight.mul(bn.running_mean).div(torch.sqrt(bn.running_var + bn.eps))\n",
#      38     "    fusedconv.bias.copy_(torch.mm(w_bn, b_conv.reshape(-1, 1)).reshape(-1) + b_bn)\n",
#      39     "\n",
#      40     "    return fusedconv\n",
#      41     "\n",
#      42     "class DFL(nn.Module):\n",
#      43     "    # DFL模块\n",
#      44     "    # Distribution Focal Loss (DFL) proposed in Generalized Focal Loss https://ieeexplore.ieee.org/document/9792391\n",
#      45     "    def __init__(self, c1=16):\n",
#      46     "        super().__init__()\n",
#      47     "        self.conv   = nn.Conv2d(c1, 1, 1, bias=False).requires_grad_(False)\n",
#      48     "        x           = torch.arange(c1, dtype=torch.float)\n",
#      49     "        self.conv.weight.data[:] = nn.Parameter(x.view(1, c1, 1, 1))\n",
#      50     "        self.c1     = c1\n",
#      51     "\n",
#      52     "    def forward(self, x):\n",
#      53     "        # bs, self.reg_max * 4, 8400\n",
#      54     "        b, c, a = x.shape\n",
#      55     "        # bs, 4, self.reg_max, 8400 => bs, self.reg_max, 4, 8400 => b, 4, 8400\n",
#      56     "        # 以softmax的方式，对0~16的数字计算百分比，获得最终数字。\n",
#      57     "        return self.conv(x.view(b, 4, self.c1, a).transpose(2, 1).softmax(1)).view(b, 4, a)\n",
#      58     "        # return self.conv(x.view(b, self.c1, 4, a).softmax(1)).view(b, 4, a)\n",
#      59     "        \n",
#      60     "#---------------------------------------------------#\n",
#      61     "#   yolo_body\n",
#      62     "#---------------------------------------------------#\n",
#      63     "class YoloBody(nn.Module):\n",
#      64     "    def __init__(self, input_shape, num_classes, phi, pretrained=False):\n",
#      65     "        super(YoloBody, self).__init__()\n",
#      66     "        depth_dict          = {'n' : 0.33, 's' : 0.33, 'm' : 0.67, 'l' : 1.00, 'x' : 1.00,}\n",
#      67     "        width_dict          = {'n' : 0.25, 's' : 0.50, 'm' : 0.75, 'l' : 1.00, 'x' : 1.25,}\n",
#      68     "        deep_width_dict     = {'n' : 1.00, 's' : 1.00, 'm' : 0.75, 'l' : 0.50, 'x' : 0.50,}\n",
#      69     "        dep_mul, wid_mul, deep_mul = depth_dict[phi], width_dict[phi], deep_width_dict[phi]\n",
#      70     "\n",
#      71     "        base_channels       = int(wid_mul * 64)  # 64\n",
#      72     "        base_depth          = max(round(dep_mul * 3), 1)  # 3\n",
#      73     "        #-----------------------------------------------#\n",
#      74     "        #   输入图片是3, 640, 640\n",
#      75     "        #-----------------------------------------------#\n",
#      76     "\n",
#      77     "        #---------------------------------------------------#   \n",
#      78     "        #   生成主干模型\n",
#      79     "        #   获得三个有效特征层，他们的shape分别是：\n",
#      80     "        #   256, 80, 80\n",
#      81     "        #   512, 40, 40\n",
#      82     "        #   1024 * deep_mul, 20, 20\n",
#      83     "        #---------------------------------------------------#\n",
#      84     "        self.backbone   = Backbone(base_channels, base_depth, deep_mul, phi, pretrained=pretrained)\n",
#      85     "\n",
#      86     "        #------------------------加强特征提取网络------------------------# \n",
#      87     "        self.upsample   = nn.Upsample(scale_factor=2, mode=\"nearest\")\n",
#      88     "\n",
#      89     "        # 1024 * deep_mul + 512, 40, 40 => 512, 40, 40\n",
#      90     "        self.conv3_for_upsample1    = C2f(int(base_channels * 16 * deep_mul) + base_channels * 8, base_channels * 8, base_depth, shortcut=False)\n",
#      91     "        # 768, 80, 80 => 256, 80, 80\n",
#      92     "        self.conv3_for_upsample2    = C2f(base_channels * 8 + base_channels * 4, base_channels * 4, base_depth, shortcut=False)\n",
#      93     "        \n",
#      94     "        # 256, 80, 80 => 256, 40, 40\n",
#      95     "        self.down_sample1           = Conv(base_channels * 4, base_channels * 4, 3, 2)\n",
#      96     "        # 512 + 256, 40, 40 => 512, 40, 40\n",
#      97     "        self.conv3_for_downsample1  = C2f(base_channels * 8 + base_channels * 4, base_channels * 8, base_depth, shortcut=False)\n",
#      98     "\n",
#      99     "        # 512, 40, 40 => 512, 20, 20\n",
#     100     "        self.down_sample2           = Conv(base_channels * 8, base_channels * 8, 3, 2)\n",
#     101     "        # 1024 * deep_mul + 512, 20, 20 =>  1024 * deep_mul, 20, 20\n",
#     102     "        self.conv3_for_downsample2  = C2f(int(base_channels * 16 * deep_mul) + base_channels * 8, int(base_channels * 16 * deep_mul), base_depth, shortcut=False)\n",
#     103     "        #------------------------加强特征提取网络------------------------# \n",
#     104     "        \n",
#     105     "        ch              = [base_channels * 4, base_channels * 8, int(base_channels * 16 * deep_mul)]\n",
#     106     "        self.shape      = None\n",
#     107     "        self.nl         = len(ch)\n",
#     108     "        # self.stride     = torch.zeros(self.nl)\n",
#     109     "        self.stride     = torch.tensor([256 / x.shape[-2] for x in self.backbone.forward(torch.zeros(1, 3, 256, 256))])  # forward\n",
#     110     "        self.reg_max    = 16  # DFL channels (ch[0] // 16 to scale 4/8/12/16/20 for n/s/m/l/x)\n",
#     111     "        self.no         = num_classes + self.reg_max * 4  # number of outputs per anchor\n",
#     112     "        self.num_classes = num_classes\n",
#     113     "        \n",
#     114     "        c2, c3   = max((16, ch[0] // 4, self.reg_max * 4)), max(ch[0], num_classes)  # channels\n",
#     115     "        self.cv2 = nn.ModuleList(nn.Sequential(Conv(x, c2, 3), Conv(c2, c2, 3), nn.Conv2d(c2, 4 * self.reg_max, 1)) for x in ch)\n",
#     116     "        self.cv3 = nn.ModuleList(nn.Sequential(Conv(x, c3, 3), Conv(c3, c3, 3), nn.Conv2d(c3, num_classes, 1)) for x in ch)\n",
#     117     "        if not pretrained:\n",
#     118     "            weights_init(self)\n",
#     119     "        self.dfl = DFL(self.reg_max) if self.reg_max > 1 else nn.Identity()\n",
#     120     "\n",
#     121     "\n",
#     122     "    def fuse(self):\n",
#     123     "        print('Fusing layers... ')\n",
# --> 124     "        for m in self.modules():\n",
#     125     "            if type(m) is Conv and hasattr(m, 'bn'):\n",
#     126     "                m.conv = fuse_conv_and_bn(m.conv, m.bn)  # update conv\n",
#     127     "                delattr(m, 'bn')  # remove batchnorm\n",
#     128     "                m.forward = m.forward_fuse  # update forward\n",
#     129     "        return self\n",
#     130     "    \n",
#     131     "    def forward(self, x):\n",
#     132     "        #  backbone\n",
#     133     "        feat1, feat2, feat3 = self.backbone.forward(x)\n",
#     134     "        \n",
#     135     "        #------------------------加强特征提取网络------------------------# \n",
#     136     "        # 1024 * deep_mul, 20, 20 => 1024 * deep_mul, 40, 40\n",
#     137     "        P5_upsample = self.upsample(feat3)\n",
#     138     "        # 1024 * deep_mul, 40, 40 cat 512, 40, 40 => 1024 * deep_mul + 512, 40, 40\n",
#     139     "        P4          = torch.cat([P5_upsample, feat2], 1)\n",
#     140     "        # 1024 * deep_mul + 512, 40, 40 => 512, 40, 40\n",
#     141     "        P4          = self.conv3_for_upsample1(P4)\n",
#     142     "\n",
#     143     "        # 512, 40, 40 => 512, 80, 80\n",
#     144     "        P4_upsample = self.upsample(P4)\n",
#     145     "        # 512, 80, 80 cat 256, 80, 80 => 768, 80, 80\n",
#     146     "        P3          = torch.cat([P4_upsample, feat1], 1)\n",
#     147     "        # 768, 80, 80 => 256, 80, 80\n",
#     148     "        P3          = self.conv3_for_upsample2(P3)\n",
#     149     "\n",
#     150     "        # 256, 80, 80 => 256, 40, 40\n",
#     151     "        P3_downsample = self.down_sample1(P3)\n",
#     152     "        # 512, 40, 40 cat 256, 40, 40 => 768, 40, 40\n",
#     153     "        P4 = torch.cat([P3_downsample, P4], 1)\n",
#     154     "        # 768, 40, 40 => 512, 40, 40\n",
#     155     "        P4 = self.conv3_for_downsample1(P4)\n",
#     156     "\n",
#     157     "        # 512, 40, 40 => 512, 20, 20\n",
#     158     "        P4_downsample = self.down_sample2(P4)\n",
#     159     "        # 512, 20, 20 cat 1024 * deep_mul, 20, 20 => 1024 * deep_mul + 512, 20, 20\n",
#     160     "        P5 = torch.cat([P4_downsample, feat3], 1)\n",
#     161     "        # 1024 * deep_mul + 512, 20, 20 => 1024 * deep_mul, 20, 20\n",
#     162     "        P5 = self.conv3_for_downsample2(P5)\n",
#     163     "        #------------------------加强特征提取网络------------------------# \n",
#     164     "        # P3 256, 80, 80\n",
#     165     "        # P4 512, 40, 40\n",
#     166     "        # P5 1024 * deep_mul, 20, 20\n",
#     167     "        shape = P3.shape  # BCHW\n",
#     168     "        \n",
#     169     "        # P3 256, 80, 80 => num_classes + self.reg_max * 4, 80, 80\n",
#     170     "        # P4 512, 40, 40 => num_classes + self.reg_max * 4, 40, 40\n",
#     171     "        # P5 1024 * deep_mul, 20, 20 => num_classes + self.reg_max * 4, 20, 20\n",
#     172     "        x = [P3, P4, P5]\n",
#     173     "        for i in range(self.nl):\n",
#     174     "            x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)\n",
#     175     "\n",
#     176     "        if self.shape != shape:\n",
#     177     "            self.anchors, self.strides = (x.transpose(0, 1) for x in make_anchors(x, self.stride, 0.5))\n",
#     178     "            self.shape = shape\n",
#     179     "        \n",
#     180     "        # num_classes + self.reg_max * 4 , 8400 =>  cls num_classes, 8400; \n",
#     181     "        #                                           box self.reg_max * 4, 8400\n",
#     182     "        box, cls        = torch.cat([xi.view(shape[0], self.no, -1) for xi in x], 2).split((self.reg_max * 4, self.num_classes), 1)\n",
#     183     "        # origin_cls      = [xi.split((self.reg_max * 4, self.num_classes), 1)[1] for xi in x]\n",
#     184     "        dbox            = self.dfl(box)\n",
#     185     "        return dbox, cls, x, self.anchors.to(dbox.device), self.strides.to(dbox.device)"
#     186    ]
#     187   }
#     188  ],
#     189  "metadata": {
#     190   "kernelspec": {
#     191    "display_name": "torch[python3.9]",
#     192    "language": "python",
#     193    "name": "pytorchuse"
#     194   },
#     195   "language_info": {
#     196    "codemirror_mode": {
#     197     "name": "ipython",
#     198     "version": 3
#     199    },
#     200    "file_extension": ".py",
#     201    "mimetype": "text/x-python",
#     202    "name": "python",
#     203    "nbconvert_exporter": "python",
#     204    "pygments_lexer": "ipython3",
#     205    "version": "3.9.19"
#     206   }
#     207  },
#     208  "nbformat": 4,
#     209  "nbformat_minor": 5
#     210 }
#
# File D:\StudyTool\jupyter-projects\Mdoule\yolov8-pytorch-master_1\nets\backbone.ipynb:131, in forward(self, x)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": null,
#       6    "id": "e077c470",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import torch\n",
#      11     "import torch.nn as nn\n",
#      12     "\n",
#      13     "\n",
#      14     "def autopad(k, p=None, d=1):  \n",
#      15     "    # kernel, padding, dilation\n",
#      16     "    # 对输入的特征层进行自动padding，按照Same原则\n",
#      17     "    if d > 1:\n",
#      18     "        # actual kernel-size\n",
#      19     "        k = d * (k - 1) + 1 if isinstance(k, int) else [d * (x - 1) + 1 for x in k]\n",
#      20     "    if p is None:\n",
#      21     "        # auto-pad\n",
#      22     "        p = k // 2 if isinstance(k, int) else [x // 2 for x in k]\n",
#      23     "    return p\n",
#      24     "\n",
#      25     "class SiLU(nn.Module):  \n",
#      26     "    # SiLU激活函数\n",
#      27     "    @staticmethod\n",
#      28     "    def forward(x):\n",
#      29     "        return x * torch.sigmoid(x)\n",
#      30     "    \n",
#      31     "class Conv(nn.Module):\n",
#      32     "    # 标准卷积+标准化+激活函数\n",
#      33     "    default_act = SiLU() \n",
#      34     "    def __init__(self, c1, c2, k=1, s=1, p=None, g=1, d=1, act=True):\n",
#      35     "        super().__init__()\n",
#      36     "        self.conv   = nn.Conv2d(c1, c2, k, s, autopad(k, p, d), groups=g, dilation=d, bias=False)\n",
#      37     "        self.bn     = nn.BatchNorm2d(c2, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)\n",
#      38     "        self.act    = self.default_act if act is True else act if isinstance(act, nn.Module) else nn.Identity()\n",
#      39     "\n",
#      40     "    def forward(self, x):\n",
#      41     "        return self.act(self.bn(self.conv(x)))\n",
#      42     "\n",
#      43     "    def forward_fuse(self, x):\n",
#      44     "        return self.act(self.conv(x))\n",
#      45     "\n",
#      46     "class Bottleneck(nn.Module):\n",
#      47     "    # 标准瓶颈结构，残差结构\n",
#      48     "    # c1为输入通道数，c2为输出通道数\n",
#      49     "    def __init__(self, c1, c2, shortcut=True, g=1, k=(3, 3), e=0.5):\n",
#      50     "        super().__init__()\n",
#      51     "        c_ = int(c2 * e)  # hidden channels\n",
#      52     "        self.cv1 = Conv(c1, c_, k[0], 1)\n",
#      53     "        self.cv2 = Conv(c_, c2, k[1], 1, g=g)\n",
#      54     "        self.add = shortcut and c1 == c2\n",
#      55     "\n",
#      56     "    def forward(self, x):\n",
#      57     "        return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))    \n",
#      58     "\n",
#      59     "class C2f(nn.Module):\n",
#      60     "    # CSPNet结构结构，大残差结构\n",
#      61     "    # c1为输入通道数，c2为输出通道数\n",
#      62     "    def __init__(self, c1, c2, n=1, shortcut=False, g=1, e=0.5):\n",
#      63     "        super().__init__()\n",
#      64     "        self.c      = int(c2 * e) \n",
#      65     "        self.cv1    = Conv(c1, 2 * self.c, 1, 1)\n",
#      66     "        self.cv2    = Conv((2 + n) * self.c, c2, 1)\n",
# ...
#     104     "        )\n",
#     105     "        # 128, 160, 160 => 256, 80, 80 => 256, 80, 80\n",
#     106     "        self.dark3 = nn.Sequential(\n",
#     107     "            Conv(base_channels * 2, base_channels * 4, 3, 2),\n",
#     108     "            C2f(base_channels * 4, base_channels * 4, base_depth * 2, True),\n",
#     109     "        )\n",
#     110     "        # 256, 80, 80 => 512, 40, 40 => 512, 40, 40\n",
#     111     "        self.dark4 = nn.Sequential(\n",
#     112     "            Conv(base_channels * 4, base_channels * 8, 3, 2),\n",
#     113     "            C2f(base_channels * 8, base_channels * 8, base_depth * 2, True),\n",
#     114     "        )\n",
#     115     "        # 512, 40, 40 => 1024 * deep_mul, 20, 20 => 1024 * deep_mul, 20, 20\n",
#     116     "        self.dark5 = nn.Sequential(\n",
#     117     "            Conv(base_channels * 8, int(base_channels * 16 * deep_mul), 3, 2),\n",
#     118     "            C2f(int(base_channels * 16 * deep_mul), int(base_channels * 16 * deep_mul), base_depth, True),\n",
#     119     "            SPPF(int(base_channels * 16 * deep_mul), int(base_channels * 16 * deep_mul), k=5)\n",
#     120     "        )\n",
#     121     "        \n",
#     122     "        if pretrained:\n",
#     123     "            url = {\n",
#     124     "                \"n\" : 'https://github.com/bubbliiiing/yolov8-pytorch/releases/download/v1.0/yolov8_n_backbone_weights.pth',\n",
#     125     "                \"s\" : 'https://github.com/bubbliiiing/yolov8-pytorch/releases/download/v1.0/yolov8_s_backbone_weights.pth',\n",
#     126     "                \"m\" : 'https://github.com/bubbliiiing/yolov8-pytorch/releases/download/v1.0/yolov8_m_backbone_weights.pth',\n",
#     127     "                \"l\" : 'https://github.com/bubbliiiing/yolov8-pytorch/releases/download/v1.0/yolov8_l_backbone_weights.pth',\n",
#     128     "                \"x\" : 'https://github.com/bubbliiiing/yolov8-pytorch/releases/download/v1.0/yolov8_x_backbone_weights.pth',\n",
#     129     "            }[phi]\n",
#     130     "            checkpoint = torch.hub.load_state_dict_from_url(url=url, map_location=\"cpu\", model_dir=\"./model_data\")\n",
#     131     "            self.load_state_dict(checkpoint, strict=False)\n",
#     132     "            print(\"Load weights from \" + url.split('/')[-1])\n",
#     133     "\n",
#     134     "    def forward(self, x):\n",
#     135     "        x = self.stem(x)\n",
#     136     "        x = self.dark2(x)\n",
#     137     "        #-----------------------------------------------#\n",
#     138     "        #   dark3的输出为256, 80, 80，是一个有效特征层\n",
#     139     "        #-----------------------------------------------#\n",
#     140     "        x = self.dark3(x)\n",
#     141     "        feat1 = x\n",
#     142     "        #-----------------------------------------------#\n",
#     143     "        #   dark4的输出为512, 40, 40，是一个有效特征层\n",
#     144     "        #-----------------------------------------------#\n",
#     145     "        x = self.dark4(x)\n",
#     146     "        feat2 = x\n",
#     147     "        #-----------------------------------------------#\n",
#     148     "        #   dark5的输出为1024 * deep_mul, 20, 20，是一个有效特征层\n",
#     149     "        #-----------------------------------------------#\n",
#     150     "        x = self.dark5(x)\n",
#     151     "        feat3 = x\n",
#     152     "        return feat1, feat2, feat3\n"
#     153    ]
#     154   }
#     155  ],
#     156  "metadata": {
#     157   "kernelspec": {
#     158    "display_name": "torch[python3.9]",
#     159    "language": "python",
#     160    "name": "pytorchuse"
#     161   },
#     162   "language_info": {
#     163    "codemirror_mode": {
#     164     "name": "ipython",
#     165     "version": 3
#     166    },
#     167    "file_extension": ".py",
#     168    "mimetype": "text/x-python",
#     169    "name": "python",
#     170    "nbconvert_exporter": "python",
#     171    "pygments_lexer": "ipython3",
#     172    "version": "3.9.19"
#     173   }
#     174  },
#     175  "nbformat": 4,
#     176  "nbformat_minor": 5
#     177 }
#
# File D:\StudyTool\Anaconda\envs\pytorchuse\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File D:\StudyTool\Anaconda\envs\pytorchuse\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File D:\StudyTool\jupyter-projects\Mdoule\yolov8-pytorch-master_1\nets\backbone.ipynb:35, in forward_fuse(self, x)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": null,
#       6    "id": "e077c470",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import torch\n",
#      11     "import torch.nn as nn\n",
#      12     "\n",
#      13     "\n",
#      14     "def autopad(k, p=None, d=1):  \n",
#      15     "    # kernel, padding, dilation\n",
#      16     "    # 对输入的特征层进行自动padding，按照Same原则\n",
#      17     "    if d > 1:\n",
#      18     "        # actual kernel-size\n",
#      19     "        k = d * (k - 1) + 1 if isinstance(k, int) else [d * (x - 1) + 1 for x in k]\n",
#      20     "    if p is None:\n",
#      21     "        # auto-pad\n",
#      22     "        p = k // 2 if isinstance(k, int) else [x // 2 for x in k]\n",
#      23     "    return p\n",
#      24     "\n",
#      25     "class SiLU(nn.Module):  \n",
#      26     "    # SiLU激活函数\n",
#      27     "    @staticmethod\n",
#      28     "    def forward(x):\n",
#      29     "        return x * torch.sigmoid(x)\n",
#      30     "    \n",
#      31     "class Conv(nn.Module):\n",
#      32     "    # 标准卷积+标准化+激活函数\n",
#      33     "    default_act = SiLU() \n",
#      34     "    def __init__(self, c1, c2, k=1, s=1, p=None, g=1, d=1, act=True):\n",
# ---> 35     "        super().__init__()\n",
#      36     "        self.conv   = nn.Conv2d(c1, c2, k, s, autopad(k, p, d), groups=g, dilation=d, bias=False)\n",
#      37     "        self.bn     = nn.BatchNorm2d(c2, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)\n",
#      38     "        self.act    = self.default_act if act is True else act if isinstance(act, nn.Module) else nn.Identity()\n",
#      39     "\n",
#      40     "    def forward(self, x):\n",
#      41     "        return self.act(self.bn(self.conv(x)))\n",
#      42     "\n",
#      43     "    def forward_fuse(self, x):\n",
#      44     "        return self.act(self.conv(x))\n",
#      45     "\n",
#      46     "class Bottleneck(nn.Module):\n",
#      47     "    # 标准瓶颈结构，残差结构\n",
#      48     "    # c1为输入通道数，c2为输出通道数\n",
#      49     "    def __init__(self, c1, c2, shortcut=True, g=1, k=(3, 3), e=0.5):\n",
#      50     "        super().__init__()\n",
#      51     "        c_ = int(c2 * e)  # hidden channels\n",
#      52     "        self.cv1 = Conv(c1, c_, k[0], 1)\n",
#      53     "        self.cv2 = Conv(c_, c2, k[1], 1, g=g)\n",
#      54     "        self.add = shortcut and c1 == c2\n",
#      55     "\n",
#      56     "    def forward(self, x):\n",
#      57     "        return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))    \n",
#      58     "\n",
#      59     "class C2f(nn.Module):\n",
#      60     "    # CSPNet结构结构，大残差结构\n",
#      61     "    # c1为输入通道数，c2为输出通道数\n",
#      62     "    def __init__(self, c1, c2, n=1, shortcut=False, g=1, e=0.5):\n",
#      63     "        super().__init__()\n",
#      64     "        self.c      = int(c2 * e) \n",
#      65     "        self.cv1    = Conv(c1, 2 * self.c, 1, 1)\n",
#      66     "        self.cv2    = Conv((2 + n) * self.c, c2, 1)\n",
#      67     "        self.m      = nn.ModuleList(Bottleneck(self.c, self.c, shortcut, g, k=((3, 3), (3, 3)), e=1.0) for _ in range(n))\n",
#      68     "\n",
#      69     "    def forward(self, x):\n",
#      70     "        # 进行一个卷积，然后划分成两份，每个通道都为c\n",
#      71     "        y = list(self.cv1(x).split((self.c, self.c), 1))\n",
#      72     "        # 每进行一次残差结构都保留，然后堆叠在一起，密集残差\n",
#      73     "        y.extend(m(y[-1]) for m in self.m)\n",
#      74     "        return self.cv2(torch.cat(y, 1))\n",
#      75     "    \n",
#      76     "class SPPF(nn.Module):\n",
#      77     "    # SPP结构，5、9、13最大池化核的最大池化。\n",
#      78     "    def __init__(self, c1, c2, k=5):\n",
#      79     "        super().__init__()\n",
#      80     "        c_          = c1 // 2\n",
#      81     "        self.cv1    = Conv(c1, c_, 1, 1)\n",
#      82     "        self.cv2    = Conv(c_ * 4, c2, 1, 1)\n",
#      83     "        self.m      = nn.MaxPool2d(kernel_size=k, stride=1, padding=k // 2)\n",
#      84     "\n",
#      85     "    def forward(self, x):\n",
#      86     "        x = self.cv1(x)\n",
#      87     "        y1 = self.m(x)\n",
#      88     "        y2 = self.m(y1)\n",
#      89     "        return self.cv2(torch.cat((x, y1, y2, self.m(y2)), 1))\n",
#      90     "\n",
#      91     "class Backbone(nn.Module):\n",
#      92     "    def __init__(self, base_channels, base_depth, deep_mul, phi, pretrained=False):\n",
#      93     "        super().__init__()\n",
#      94     "        #-----------------------------------------------#\n",
#      95     "        #   输入图片是3, 640, 640\n",
#      96     "        #-----------------------------------------------#\n",
#      97     "        # 3, 640, 640 => 32, 640, 640 => 64, 320, 320\n",
#      98     "        self.stem = Conv(3, base_channels, 3, 2)\n",
#      99     "        \n",
#     100     "        # 64, 320, 320 => 128, 160, 160 => 128, 160, 160\n",
#     101     "        self.dark2 = nn.Sequential(\n",
#     102     "            Conv(base_channels, base_channels * 2, 3, 2),\n",
#     103     "            C2f(base_channels * 2, base_channels * 2, base_depth, True),\n",
#     104     "        )\n",
#     105     "        # 128, 160, 160 => 256, 80, 80 => 256, 80, 80\n",
#     106     "        self.dark3 = nn.Sequential(\n",
#     107     "            Conv(base_channels * 2, base_channels * 4, 3, 2),\n",
#     108     "            C2f(base_channels * 4, base_channels * 4, base_depth * 2, True),\n",
#     109     "        )\n",
#     110     "        # 256, 80, 80 => 512, 40, 40 => 512, 40, 40\n",
#     111     "        self.dark4 = nn.Sequential(\n",
#     112     "            Conv(base_channels * 4, base_channels * 8, 3, 2),\n",
#     113     "            C2f(base_channels * 8, base_channels * 8, base_depth * 2, True),\n",
#     114     "        )\n",
#     115     "        # 512, 40, 40 => 1024 * deep_mul, 20, 20 => 1024 * deep_mul, 20, 20\n",
#     116     "        self.dark5 = nn.Sequential(\n",
#     117     "            Conv(base_channels * 8, int(base_channels * 16 * deep_mul), 3, 2),\n",
#     118     "            C2f(int(base_channels * 16 * deep_mul), int(base_channels * 16 * deep_mul), base_depth, True),\n",
#     119     "            SPPF(int(base_channels * 16 * deep_mul), int(base_channels * 16 * deep_mul), k=5)\n",
#     120     "        )\n",
#     121     "        \n",
#     122     "        if pretrained:\n",
#     123     "            url = {\n",
#     124     "                \"n\" : 'https://github.com/bubbliiiing/yolov8-pytorch/releases/download/v1.0/yolov8_n_backbone_weights.pth',\n",
#     125     "                \"s\" : 'https://github.com/bubbliiiing/yolov8-pytorch/releases/download/v1.0/yolov8_s_backbone_weights.pth',\n",
#     126     "                \"m\" : 'https://github.com/bubbliiiing/yolov8-pytorch/releases/download/v1.0/yolov8_m_backbone_weights.pth',\n",
#     127     "                \"l\" : 'https://github.com/bubbliiiing/yolov8-pytorch/releases/download/v1.0/yolov8_l_backbone_weights.pth',\n",
#     128     "                \"x\" : 'https://github.com/bubbliiiing/yolov8-pytorch/releases/download/v1.0/yolov8_x_backbone_weights.pth',\n",
#     129     "            }[phi]\n",
#     130     "            checkpoint = torch.hub.load_state_dict_from_url(url=url, map_location=\"cpu\", model_dir=\"./model_data\")\n",
#     131     "            self.load_state_dict(checkpoint, strict=False)\n",
#     132     "            print(\"Load weights from \" + url.split('/')[-1])\n",
#     133     "\n",
#     134     "    def forward(self, x):\n",
#     135     "        x = self.stem(x)\n",
#     136     "        x = self.dark2(x)\n",
#     137     "        #-----------------------------------------------#\n",
#     138     "        #   dark3的输出为256, 80, 80，是一个有效特征层\n",
#     139     "        #-----------------------------------------------#\n",
#     140     "        x = self.dark3(x)\n",
#     141     "        feat1 = x\n",
#     142     "        #-----------------------------------------------#\n",
#     143     "        #   dark4的输出为512, 40, 40，是一个有效特征层\n",
#     144     "        #-----------------------------------------------#\n",
#     145     "        x = self.dark4(x)\n",
#     146     "        feat2 = x\n",
#     147     "        #-----------------------------------------------#\n",
#     148     "        #   dark5的输出为1024 * deep_mul, 20, 20，是一个有效特征层\n",
#     149     "        #-----------------------------------------------#\n",
#     150     "        x = self.dark5(x)\n",
#     151     "        feat3 = x\n",
#     152     "        return feat1, feat2, feat3\n"
#     153    ]
#     154   }
#     155  ],
#     156  "metadata": {
#     157   "kernelspec": {
#     158    "display_name": "torch[python3.9]",
#     159    "language": "python",
#     160    "name": "pytorchuse"
#     161   },
#     162   "language_info": {
#     163    "codemirror_mode": {
#     164     "name": "ipython",
#     165     "version": 3
#     166    },
#     167    "file_extension": ".py",
#     168    "mimetype": "text/x-python",
#     169    "name": "python",
#     170    "nbconvert_exporter": "python",
#     171    "pygments_lexer": "ipython3",
#     172    "version": "3.9.19"
#     173   }
#     174  },
#     175  "nbformat": 4,
#     176  "nbformat_minor": 5
#     177 }
#
# File D:\StudyTool\Anaconda\envs\pytorchuse\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File D:\StudyTool\Anaconda\envs\pytorchuse\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File D:\StudyTool\Anaconda\envs\pytorchuse\lib\site-packages\torch\nn\modules\conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File D:\StudyTool\Anaconda\envs\pytorchuse\lib\site-packages\torch\nn\modules\conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
